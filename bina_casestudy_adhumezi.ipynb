# %% [markdown]
# <a href="https://colab.research.google.com/github/michaelzimmermannstudhslu/BINA_2024_energy_research/blob/main/bina_casestudy_adhumezi.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Basics zur Case Study

# %% [markdown]
# **Intro**
#
# Hey Leute ich hab mal ein Colab für uns erstellt, wo wir gemeinsam brauchen können.
#
#
# **Vorschlag Projektplan**
#
# 1. Datensammlung und –vorbereitung (bis Ende März)
# 2. Datenanalyse (20.04.2024 (April))
# 3. Informationsinterpretation (20.05.2024 (Mai))
# 4. Entscheidungsfindung (30.05.2024 (Mai))
# 5. Review (bis 15. Juni 2024)
# 6. Abgabe (21. Juni 2024)
#
#
# **Aufgabenstellung zur Wiederholung**
#
#
#
# *   **Vision**: Exemplarisches Durcharbeiten der notwendigen Schritte auf dem  Weg «Von Daten zu Entscheidungen»
# Hilfen: Die Case Study soll sich am Framework der CPA* Management Accounting Guideline „From Data to Decisions“ orientieren. Primär sind dabei die Schritte 1-4 zu bearbeiten.
#
#
# *   **Scope**: Der Kontext für die Case Study kann dabei durch die Gruppe individuell gewählt und definiert werden (bspw. Unternehmen, Branche, Domäne, Fachgebiet etc.)
#
#
#
#
#
# **Lieferobjekt**
#
#
# Der Abgabetermin für die Case Study (LN2) ist ***Freitag 21. Juni 2024*** (end-of-day):
#
# *   Bericht als **Jupyter Notebook als Colab Link** und
# *   als **.ipynb File** per eMail an daniel.benninger@hslu.ch.
#
#
# Alternativ kann, anstelle des Colab Links auch der Link auf eine Github Ablage (Repository) zugestellt werden. Achtung: bei privaten Repositories bitte mir den Zugriff ebenfalls ermöglichen!
#
# **Dokumentation und Erarbeitung**
#
# Jupyter/Notebook: Dokumentieren und erarbeiten Sie Ihre Case
#
# Study als Jupyter Notebook. Dies ermöglicht eine interaktive und nachvollziehbare Darstellung Ihrer Analyse und Ergebnisse.
#
# Inhalte: Stellen Sie sicher, dass Ihr Notebook folgende Aspekte beinhaltet:
#
# *   **Einleitung**: Kurze Vorstellung des gewählten Kontexts und der Zielsetzung.
#
# *   **Ziele und Informationsbedarf**: Definition der spezifischen Ziele Ihrer Case Study und des Informationsbedarfs zur Erreichung dieser Ziele.
#
# *   **Datensammlung und -beschaffung:** Beschreibung, wie und woher die Daten gesammelt wurden.
#
# *   **Datenanalyse**: Darstellung der Analysemethoden und -werkzeuge, die verwendet wurden, um Einsichten aus den Daten zu gewinnen.
#
# *   **Präsentation der Ergebnisse**: Visualisierung und Interpretation der Analyseergebnisse, die zu den Entscheidungen geführt haben.
#
#
# Durch die sorgfältige Planung und Zusammenarbeit innerhalb Ihrer Gruppe können Sie eine fundierte und überzeugende Case Study erstellen, die die kritischen Schritte von der Datensammlung bis zur Entscheidungsfindung erfolgreich demonstriert.
#
# **Bewertung und Gewichtung**:
#
#     Ziele und Informationsbedarf (20%)
#     Datensammlung, -beschaffung (10%)
#     Datenanalyse (40%)
#     Präsentation der Ergebnisse (30%)
# ---

# %% [markdown]
# # 1. Einleitung
#
# nochnals überarbeiten!!!!

# %% [markdown]
# ## 1.1 Ausgangslage

# %% [markdown]
# Energie in einer Welt, die von technologischem Fortschritt und wirtschaftlicher Entwicklung geprägt ist, spielt Energie eine zentrale Rolle. Sie ist der Treibstoff für die industrielle Produktion, den Transport, die Beleuchtung und die Heizung, und sie ist unerlässlich für das tägliche Leben. Doch während die Nachfrage nach Energie stetig steigt, sind wir uns zunehmend bewusst geworden, dass ihre Nutzung Auswirkungen auf die Umwelt und das Klima hat.
#
# Die Schweiz, ein Land mit einer florierenden Wirtschaft und einer hohen Lebensqualität, ist keine Ausnahme in dieser globalen Dynamik. Seit den 1980er Jahren hat die Schweiz eine Reihe von Maßnahmen ergriffen, um ihren Energieverbrauch zu steuern und ihre Energieeffizienz zu verbessern. Diese Bemühungen wurden durch verschiedene politische, wirtschaftliche und technologische Entwicklungen beeinflusst und geprägt.
#
# Das primäre Ziel dieser Arbeit ist es, anhand von Daten zu analysieren, wie sich der Energieverbrauch und die Energieeffizienz in der Schweiz seit 1980 verändert und entwickelt haben. Durch eine umfassende Untersuchung dieser Entwicklung können wir ein besseres Verständnis dafür gewinnen, welche Faktoren den Energieverbrauch beeinflussen und welche Maßnahmen erfolgreich waren, um die Energieeffizienz zu steigern. Darüber hinaus können wir mögliche Herausforderungen und Chancen identifizieren, denen die Schweiz in Zukunft gegenübersteht, wenn es darum geht, eine nachhaltige Energiezukunft zu gestalten.

# %% [markdown]
# ## 1.2 Ziele (Vorschläge)

# %% [markdown]
# Das primäre Ziel dieser Arbeit ist es, anhand von Daten zu analysieren, wie sich der Energiekonsum und die Energieeffizienz in der Schweiz seit 1980 verändert und entwickelt haben. Dabei wird die Zielsetzung in zwei zentrale Fragestellungen mit zwei Fragebereichen unterteilt:
#
# 1. Wie hat sich der Energieverbrauch in der Schweiz seit 1980 in den folgenden Bereichen verändert und entwickelt?
#
# *   Energiekonsum (gesamter Konsum)
# *   Energieformen (alles in CH)
# *   Erneuerbare Energien
# *   Nicht erneuerbare Energien
#
#
#
#
# 2. Lässt sich eine Zunahme der Energieeffizienz seit 1980 im Verhältnis zum Bruttoinlandprodukts und zum Bevölkerungswachstums feststellen?
#
#
# *   Bevölkerung
# *   Bruttoinlandprodukt
# *   Energieverbrauch
# *   Energiepreise
#
#
#
# 3. Wie hat sich die Energieverbrauch in den Ländern A, B und C im Vergleich zur Schweiz in den folgenden Bereichen verändert und entwickelt?
#
# *   Energiekonsum (gesamter Konsum)
# *   Energieformen (alles in CH)
# *   Erneuerbare Energien
# *   Nicht erneuerbare Energien

# %% [markdown]
# ## 1.3 Vorgehen

# %% [markdown]
# Im Rahmen dieser Arbeit wird nach dem fünfstufigen Modell des Chartered Professional Accountants (CPA) "From Data to Decision" vorgegangen (siehe Abbildung 1). Der letzte Schritt wird in dieser Arbeit nicht behandelt:

# %% [markdown]
# ![CPA.PNG](data:image/png;base64,...)

# %% [markdown]
# Abbildung 1: CPA Management Accounting Guideline (Quelle: CPA 2021)

# %% [markdown]
# **Step 1**
#
# Im Rahmen des ersten Schrittes werden die Ziele und Informationsbedürfnisse festegelegt. Dabei werden die Fragen beantwortet, was sind die strategischen Ziele sind und was genau auf der Basis dieser Ziele bekannt sein muss?
#
# **Step 2**
#
# Im zweiten Schritt gilt es die definierten Daten und Informationen zu sammeln und zu organisieren. Ziel dabei ist, sicherzustellen, dass die gesammelten Daten mit im ersten Schritt festegelegten Ziele mit den gefundenen Daten erreicht werden können.
#
# **Step 3**
#
# Beim Schritt 3 werden die gewonnen Daten analysiert, um aus den analysierten Daten Informationen extrahieren zu können. Dieser Schritt umfasst dabei die Analyse sämtliche Daten, um alle definierten Fragen und Teilfragestellungen beantworten zu können.
#
# **Step 4**
#
# Im Schritt 4 werden die Daten aufbereitet und präsentiert. Dazu werden Slides erarbeitet, welche die Ergebnisse der Analyse präsentieren.

# %% [markdown]
# # 2. Definition Ziele und Festlegung der Daten
#
# Die effektiven Ziele wurden im Kapitel 1.2 definiert. Nachfolgend werden die vordefinierten Ziele in die entsprechenden Unterkapitel aufgeteilt und festgehalten, welche Datensätze dafür benötigt werden.

# %% [markdown]
# ## 2.1 Energie

# %% [markdown]
# Beim Thema Energie wird analysiert, wie sich die Energienutzung und der Energiekonsum entwickelt haben. Deshalb wurden nachfoglende Fragestellungen festgelegt:
#
# - Wie hat sich der Energiekonsum in Bezug zu den Energiequellen bzw. Energieträger verändert? Gibt es eine Trendaussage zum Energieverbrauch seit 1980 bis heute und ist erkennbar, dass mit den Massnahmen die Klimaziele der Schweiz umgesetzt werden und Wirkung zeigen? (--> eine Darstellung mit allen Entwicklungen)
#
# - Wie hat sich der Energiekonsum in den einzelnen Sektoren entwickelt? Mit dieser Frage wird analysiert, wie sich der Verbrauch entwickelt hat. Das Ziel ist es, darzustellen, wie sich der jeweilige Sektor in Bezug auf die Energieeffizienz entwickelt hat (--> eine Darstellung mit allen Entwicklungen)
#
# Anhand der oben genannten Fragen wird ersichtlich, ob Massnahmen realisiert werden und wie sie diese auf die Klimaziele auswirken. Die Schweiz verfolgt dabei nachfolgende Ziele, um bis 2050 das Netto-Null-Treibhausgas-Emissionen zu erreichen:
#
# *   Ausstieg aus der Kernenergie
# *   Ausbau erneuerbarer Energien (mit und ohne Wasserkraft, Photovoltaik)
# *   Erhöhung der Energieeffizienz
#
#
# Quellen: https://www.energie-experten.ch/de/detail/die-kernelemente-der-energiestrategie-2050.html
#
# https://www.bafu.admin.ch/bafu/de/home/themen/klima/inkuerze.html
#
# https://www.meteoschweiz.admin.ch/klima/klimawandel/globaler-klimawandel-aktueller-wissensstand/klimaziele.html
#
# ### 2.1.1 Benötigte Daten
# Um die oben definierten Fragestellungen beantworten zu können, benötigt die Projektgruppe die nachfolgenden Datenquellen und -sätze.
#
# - Energiearten (erneuerbar und nicht-erneuerbare)
# - Energieträger
# - Energieformen
# - Energiequellen
# - Energiekonsum (gesamt, pro Kopf)
# - Preis pro kWh

# %% [markdown]
# ## 2.2 Demographie & Wirtschaft

# %% [markdown]
# Im Themenbereich Demographie & Wirtschaft wird analysiert, wie sich die Energieenffizienz entwickelt hat. Dazu wurden folgende Fragestellungen festgelegt:
#
# *   Wie hat sich der Energieverbrauch im Verhältnis zur Bevölkerung entwickelt? Mit dieser Frage soll analyisert werden, ob eine effizienter Umgang mit Energie stattfindet. (--> eine Darstellung mit Entwicklung)
#
# - Wie hat sich der Energiekonsum im Verhältnis zum BIP entwickelt? Mit dieser Frage soll analyisiert werden, ob eine effizientere Nutzung von Energie stattfindet. (--> eine Darstellung mit Entwicklung)
#
#
# - Gibt es einen Zusammenhang zwischen der Bevölkerungsentwicklung und dem Energiekonsum? Mit dieser Frage soll analysiert werden, ob es eine Korrelation zwischen Bevölkerung und Energieverbrauch gibt. (--> eine Darstellung mit Entwicklung)
#
# - Wie entwickelt sich die Energieeffizienz der Schweiz im Vergleich zum Land A, Land B und Land C. Es soll analysiert werden, welches Land eine bessere Entwicklung der Energieeffizienz aufweist. (--> eine Darstellung mit allen Entwicklungen der betrachteten Länder)

# %% [markdown]
# Zusammenfassung aller Daten:
#
# Um die oben definierten Fragestellungen beantworten zu können, benötigt die Projektgruppe die nachfolgenden Datenquellen und -sätze.
#
# - Energiearten (erneuerbar und nicht-erneuerbare)
# - Energieträger
# - Energieformen
# - Energiequellen
# - Energiekonsum (gesamt, pro Kopf)
# - Preis pro kWh
# - Einwohneranzahl der Schweiz
# - BIP (gesamt, pro Kopf)
# - Inflationsrate

# %% [markdown]
# # 3. Daten sammeln

# %% [markdown]
# ## 3.1 Datenquellen

# %% [markdown]
# Für die vorliegende Arbeit wurden diverse Datenquellen berücksichtigt. Diese stammen dabei von den nachfolgenden Plattformen:
#
# *   https://databank.worldbank.org/source/sustainable-energy-for-all/preview/on#
# - Bundesamt für Statisitk [BFS]
# - Bundesamt für Energie [BAFU]
#
# Dabei ist aufgefallen, dass nicht über die ursprüngliche Beobachtungsperiode alle Daten konsistent verfügbar waren, daher wurde die beobachtete Periode auf 1980 bis 2022 eingeschränkt. Sämtliche Rohdaten wurden im CSV-Format bezogen und wurden auf Github hinterlegt.

# %% [markdown]
# ## 3.1 Daten importieren, aufbereiten und transformation

# %% [markdown]
# Der Datenimport und die -Verarbeitung erfolgt mit pandas. Die Datenbibliothek wird als pd importiert.

# %%
import pandas as pd

# %% [markdown]
# Die Datensätze sind in GitHub in einem Repository hinterlegt. Dies war der Projektgruppe wichtig, damit die Arbeit unabhängig erfolgen kann.

# %%
# Notwendige Bibliotheken laden
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# Daten aus Github einlesen

sourceFILE = '...'

# Spaltennamen definieren
setNames = ['Spalte1', 'Spalte2', '...']


# Erste fünf Zeilen ausgeben
data = pd.read.csv(sourceFILE, names=setNames, nrows=4)
data.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-13-65900bd46310> in <cell line: 16>()
#      14
#      15 # Erste fünf Zeilen ausgeben
# ---> 16 data = pd.read.csv(sourceFILE, names=setNames, nrows=4)
#      17 data.head()
#
# AttributeError: module 'pandas' has no attribute 'read'

# %% [markdown]
# # Wirtschafts Daten (BIP)

# %% [markdown]
# ## BIP Total
#
# 3.1.1. Wirtschaftsdaten
#
# Für die Datenanalyse im Bereich Wirtschaft wurden folgende Daten gesammelt:
#
# Bevölkerungszahl der Schweiz
# Gesamt- und Pro-Kopf-Bruttoinlandsprodukt
# Inflationsrate der Schweiz
# Die Entwicklung

# %%
import pandas as pd

df = pd.read_csv('https://raw.githubusercontent.com/michaelzimmermannstudhslu/BINA_2024_energy_research/main/data/bip_total.csv')

#probably better down the line for calculations and graphics but int looks nicer in the table
#df['Jahr'] = pd.to_datetime(df['Jahr'], format='%Y')

# Assuming we have a columns 'Bevölkerung' and 'Jahr' with integers that exceed the range of int16 (-32,768 to 32,767),
# but these numbers are still within the range of int32 (-2,147,483,648 to 2,147,483,647).
# In this case, using 'int32' is necessary to correctly handle the larger numbers without overflow,
# while also being more memory-efficient than opting for 'Int64' when the numbers do not require that range.
# This choice ensures data integrity and efficient memory use.
df['Jahr'] = df['Jahr'].astype('Int64')
df['Bevölkerung'] = df['Bevölkerung'].astype('Int64')

df
# Out:
#     Jahr  Bevölkerung        BIP  Inflationsrate
# 0   1980      6335243  205370.18             4.0
# 1   1981      6372904  220471.25             6.5
# 2   1982      6409713  233572.55             5.7
# 3   1983      6427833  240628.98             2.9
# 4   1984      6455896  257187.15             2.9
# 5   1985      6484834  272689.73             3.4
# 6   1986      6523413  286186.86             0.8
# 7   1987      6566799  297101.28             1.4
# 8   1988      6619973  315400.60             1.9
# 9   1989      6673850  340440.35             3.2
# 10  1990      6750693  369198.76             5.4
# 11  1991      6842768  385605.03             5.9
# 12  1992      6907959  393625.51             4.0
# 13  1993      6968570  402258.17             3.3
# 14  1994      7019019  412190.66             0.9
# 15  1995      7062354  417228.34             1.8
# 16  1996      7081346  420368.49             0.8
# 17  1997      7096465  427826.11             0.5
# ...

# %%
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('https://raw.githubusercontent.com/michaelzimmermannstudhslu/BINA_2024_energy_research/main/data/bip_total.csv')

year = df['Jahr']
pop = df['Bevölkerung']
bip = df['BIP']

print("*******")
plt.figure(figsize=(14, 6))
plt.plot(year, pop, linewidth=2, color='grey')
plt.title('Bevölkerungsentwicklung Schweiz 1980 bis 2022')
plt.xlabel('Jahr')
plt.ylabel('Bevölkerungsanzahl in Mio')
plt.show()

print("*******")

plt.figure(figsize=(14, 6))
plt.plot(year, bip, linewidth=2, color='grey')
plt.title('BIP Entwicklung Schweiz 1980 bis 2022')
plt.xlabel('Jahr')
plt.ylabel('Bruttoinlandprodukt total in USD')
plt.show()
# Out:
# *******
# *******

# %% [markdown]
# ## BIP per Kopf

# %%
import pandas as pd

df = pd.read_csv('https://raw.githubusercontent.com/michaelzimmermannstudhslu/BINA_2024_energy_research/main/data/bip_per_head.csv')

#probably better down the line for calculations and graphics but int looks nicer in the table
#df['Jahr'] = pd.to_datetime(df['Jahr'], format='%Y')

# Assuming we have a columns 'Bevölkerung' and 'Jahr' with integers that exceed the range of int16 (-32,768 to 32,767),
# but these numbers are still within the range of int32 (-2,147,483,648 to 2,147,483,647).
# In this case, using 'int32' is necessary to correctly handle the larger numbers without overflow,
# while also being more memory-efficient than opting for 'Int64' when the numbers do not require that range.
# This choice ensures data integrity and efficient memory use.
df['Jahr'] = df['Jahr'].astype('Int64')
df['Bevölkerung'] = df['Bevölkerung'].astype('Int64')

df
# Out:
#     Jahr  Bevölkerung  BIP pro Kopf  Inflationsrate
# 0   1980      6335243      32163.32             4.0
# 1   1981      6372904      34292.34             6.5
# 2   1982      6409713      36116.28             5.7
# 3   1983      6427833      37122.79             2.9
# 4   1984      6455896      39535.94             2.9
# 5   1985      6484834      41738.30             3.4
# 6   1986      6523413      43540.14             0.8
# 7   1987      6566799      44886.05             1.4
# 8   1988      6619973      47275.56             1.9
# 9   1989      6673850      50637.84             3.2
# 10  1990      6750693      54766.83             5.4
# 11  1991      6842768      56459.71             5.9
# 12  1992      6907959      57057.36             4.0
# 13  1993      6968570      57740.06             3.3
# 14  1994      7019019      58559.21             0.9
# 15  1995      7062354      58802.08             1.8
# 16  1996      7081346      58953.01             0.8
# ...

# %% [markdown]
# # Umweltdaten

# %% [markdown]
# ## Durchschnitts Temperatur

# %%
df = pd.read_csv('https://raw.githubusercontent.com/michaelzimmermannstudhslu/BINA_2024_energy_research/main/data/environment_ch.csv', sep='\t')

#Clean up invalid rows
df_rein = df.dropna()

df_rein
# Out:
#      time   jan   feb   mar   apr    may    jun    jul    aug    sep    oct  \
# 1    1865 -3.46 -6.26 -5.91  7.01  10.10  10.98  13.98  11.16  11.89   5.21
# 2    1866 -1.31 -0.42 -1.00  4.10   4.96  12.02  12.25   9.99   9.69   5.35
# 3    1867 -3.87  0.55 -0.13  3.48   7.74  10.57  11.29  12.94  10.42   2.93
# 4    1868 -5.46 -1.54 -2.30  2.32  12.04  11.96  12.88  12.50  11.12   4.78
# 5    1869 -4.61  1.27 -4.25  4.52   8.92   8.26  14.81  10.87  10.34   2.32
# ..    ...   ...   ...   ...   ...    ...    ...    ...    ...    ...    ...
# 155  2019 -4.38  0.74  2.29  4.49   6.11  15.26  16.21  15.11  11.39   8.45
# 156  2020 -0.29  1.63  1.56  7.63   9.56  11.83  15.40  15.21  11.89   5.36
# 157  2021 -3.57  0.83  0.94  2.88   6.24  14.37  13.90  13.11  12.14   6.27
# 158  2022 -1.49 -0.14  2.37  4.62  11.49  15.36  16.96  16.13  10.08  10.44
# 159  2023 -1.62  0.07  2.65  3.70   9.34  14.93  15.97  15.57  14.29   9.70
#
# ...

# %% [markdown]
# ## co2 bilanz

# %%
df = pd.read_csv('https://raw.githubusercontent.com/michaelzimmermannstudhslu/BINA_2024_energy_research/main/data/environment_ch.csv', sep='\t')

df
# Out:
#      time   jan   feb   mar   apr    may    jun    jul    aug    sep    oct  \
# 0    1864 -7.10 -4.52  0.04  2.10   7.43   9.48  12.37  10.95   8.59   3.51
# 1    1865 -3.46 -6.26 -5.91  7.01  10.10  10.98  13.98  11.16  11.89   5.21
# 2    1866 -1.31 -0.42 -1.00  4.10   4.96  12.02  12.25   9.99   9.69   5.35
# 3    1867 -3.87  0.55 -0.13  3.48   7.74  10.57  11.29  12.94  10.42   2.93
# 4    1868 -5.46 -1.54 -2.30  2.32  12.04  11.96  12.88  12.50  11.12   4.78
# ..    ...   ...   ...   ...   ...    ...    ...    ...    ...    ...    ...
# 155  2019 -4.38  0.74  2.29  4.49   6.11  15.26  16.21  15.11  11.39   8.45
# 156  2020 -0.29  1.63  1.56  7.63   9.56  11.83  15.40  15.21  11.89   5.36
# 157  2021 -3.57  0.83  0.94  2.88   6.24  14.37  13.90  13.11  12.14   6.27
# 158  2022 -1.49 -0.14  2.37  4.62  11.49  15.36  16.96  16.13  10.08  10.44
# 159  2023 -1.62  0.07  2.65  3.70   9.34  14.93  15.97  15.57  14.29   9.70
#
# ...

# %% [markdown]
# #Energiedaten

# %% [markdown]
# ## Energie Bilanz

# %% [markdown]
# Support for third party widgets will remain active for the duration of the session. To disable support:

# %%
import pandas as pd

df = pd.read_csv('https://raw.githubusercontent.com/michaelzimmermannstudhslu/BINA_2024_energy_research/main/data/energiebilanz_ch.csv')

#Clean up invalid rows
df_rein = df.dropna()

print("Content of the csv")
print(df_rein)

# Extrahieren der einzigartigen Zeichenketten
energietraeger = pd.DataFrame(df['Energietraeger'].unique(), columns=['Energietraeger'])

print("")
print("############")
print("############")
print("############")
print("Energytrager")
print(energietraeger)

# Extrahieren der einzigartigen Zeichenketten
rubrik = pd.DataFrame(df['Rubrik'].unique(), columns=['Rubrik'])

print("")
print("############")
print("############")
print("############")
print("Gesammt Energy Verbrauch pro Jahr")

# Convert 'EnergyUsed' to numeric, set errors='coerce' to handle non-convertible values
df['TJ'] = pd.to_numeric(df['TJ'], errors='coerce')

# Drop rows where 'EnergyUsed' is NaN after conversion
df = df.dropna(subset=['TJ'])

# Convert 'EnergyUsed' to integer
df['TJ'] = df['TJ'].astype(int)

groupRubrik = df.groupby('Jahr')['TJ'].sum().reset_index()
print(groupRubrik)


print("")
print("############")
print("############")
print("############")
print("Test")


count_by_year_and_type = df.groupby(['Jahr', 'Energietraeger'])['TJ'].sum().reset_index()

print(count_by_year_and_type)


print("")
print("############")
print("############")
print("############")
print("Test")


energy_sum_by_year_and_type = df.groupby(['Jahr', 'Energietraeger'])['TJ'].sum().reset_index()
total_energy_by_year = df.groupby('Jahr')['TJ'].sum().reset_index()
total_energy_by_year.rename(columns={'TJ': 'TotalEnergy'}, inplace=True)

# Merge to get total energy per year alongside each row
merged_df = pd.merge(energy_sum_by_year_and_type, total_energy_by_year, on='Jahr')

# Calculate the percentage
merged_df['Percentage'] = (merged_df['TJ'] / merged_df['TotalEnergy']) * 100

print(merged_df)
# Out:
# Content of the csv
#       Jahr                        Rubrik                Energietraeger  \
# 0     1980               Bruttoverbrauch                  Elektrizität
# 1     1980               Bruttoverbrauch                 Erdölprodukte
# 2     1980               Bruttoverbrauch                     Fernwärme
# 3     1980               Bruttoverbrauch                           Gas
# 4     1980               Bruttoverbrauch                   Holzenergie
# ...    ...                           ...                           ...
# 8982  2022  Nichtenergetischer Verbrauch                         Kohle
# 8983  2022  Nichtenergetischer Verbrauch     Müll und Industrieabfälle
# 8984  2022  Nichtenergetischer Verbrauch                         Rohöl
# 8985  2022  Nichtenergetischer Verbrauch  Uebrige erneuerbare Energien
# 8986  2022  Nichtenergetischer Verbrauch                   Wasserkraft
#
#                          TJ
# 0                    -29450
# 1                    321250
# ...

# %%
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('https://raw.githubusercontent.com/michaelzimmermannstudhslu/BINA_2024_energy_research/main/data/energiebilanz_ch.csv')

year = df['Jahr']
tj = df['TJ']

# %% [markdown]
# # 4. Daten analysieren

# %% [markdown]
# Lorem ipsum dolor sit amet, consectetur adipiscing elit, sed do eiusmod tempor incididunt ut labore et dolore magna aliqua. Ut enim ad minim veniam, quis nostrud exercitation ullamco laboris nisi ut aliquip ex ea commodo consequat. Duis aute irure dolor in reprehenderit in voluptate velit esse cillum dolore eu fugiat nulla pariatur. Excepteur sint occaecat cupidatat non proident, sunt in culpa qui officia deserunt mollit anim id est laborum.

# %% [markdown]
# # 5. Ergebnisse präsentieren

# %% [markdown]
# ## 5.1 ...

# %% [markdown]
# Lorem ipsum dolor sit amet, consectetur adipiscing elit, sed do eiusmod tempor incididunt ut labore et dolore magna aliqua. Ut enim ad minim veniam, quis nostrud exercitation ullamco laboris nisi ut aliquip ex ea commodo consequat. Duis aute irure dolor in reprehenderit in voluptate velit esse cillum dolore eu fugiat nulla pariatur. Excepteur sint occaecat cupidatat non proident, sunt in culpa qui officia deserunt mollit anim id est laborum.

# %% [markdown]
# ## 5.2 Experimente

# %% [markdown]
# Lorem ipsum dolor sit amet, consectetur adipiscing elit, sed do eiusmod tempor incididunt ut labore et dolore magna aliqua. Ut enim ad minim veniam, quis nostrud exercitation ullamco laboris nisi ut aliquip ex ea commodo consequat. Duis aute irure dolor in reprehenderit in voluptate velit esse cillum dolore eu fugiat nulla pariatur. Excepteur sint occaecat cupidatat non proident, sunt in culpa qui officia deserunt mollit anim id est laborum.

# %% [markdown]
# # 6. Datengetriebene Entscheidungsfindung

# %% [markdown]
# ## 6.1 ...

# %% [markdown]
# Lorem ipsum dolor sit amet, consectetur adipiscing elit, sed do eiusmod tempor incididunt ut labore et dolore magna aliqua. Ut enim ad minim veniam, quis nostrud exercitation ullamco laboris nisi ut aliquip ex ea commodo consequat. Duis aute irure dolor in reprehenderit in voluptate velit esse cillum dolore eu fugiat nulla pariatur. Excepteur sint occaecat cupidatat non proident, sunt in culpa qui officia deserunt mollit anim id est laborum.

# %% [markdown]
# ## 6.2 ...

# %% [markdown]
# Lorem ipsum dolor sit amet, consectetur adipiscing elit, sed do eiusmod tempor incididunt ut labore et dolore magna aliqua. Ut enim ad minim veniam, quis nostrud exercitation ullamco laboris nisi ut aliquip ex ea commodo consequat. Duis aute irure dolor in reprehenderit in voluptate velit esse cillum dolore eu fugiat nulla pariatur. Excepteur sint occaecat cupidatat non proident, sunt in culpa qui officia deserunt mollit anim id est laborum.
