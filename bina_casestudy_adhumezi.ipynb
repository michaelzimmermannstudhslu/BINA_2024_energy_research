# %% [markdown]
# <a href="https://colab.research.google.com/github/michaelzimmermannstudhslu/BINA_2024_energy_research/blob/main/bina_casestudy_adhumezi.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Basics zur Case Study

# %% [markdown]
# **Intro**
#
# Hey Leute ich hab mal ein Colab für uns erstellt, wo wir gemeinsam brauchen können.
#
#
# **Vorschlag Projektplan**
#
# 1. Datensammlung und –vorbereitung (bis Ende März)
# 2. Datenanalyse (20.04.2024 (April))
# 3. Informationsinterpretation (20.05.2024 (Mai))
# 4. Entscheidungsfindung (30.05.2024 (Mai))
# 5. Review (bis 15. Juni 2024)
# 6. Abgabe (21. Juni 2024)
#
#
# **Aufgabenstellung zur Wiederholung**
#
#
#
# *   **Vision**: Exemplarisches Durcharbeiten der notwendigen Schritte auf dem  Weg «Von Daten zu Entscheidungen»
# Hilfen: Die Case Study soll sich am Framework der CPA* Management Accounting Guideline „From Data to Decisions“ orientieren. Primär sind dabei die Schritte 1-4 zu bearbeiten.
#
#
# *   **Scope**: Der Kontext für die Case Study kann dabei durch die Gruppe individuell gewählt und definiert werden (bspw. Unternehmen, Branche, Domäne, Fachgebiet etc.)
#
#
#
#
#
# **Lieferobjekt**
#
#
# Der Abgabetermin für die Case Study (LN2) ist ***Freitag 21. Juni 2024*** (end-of-day):
#
# *   Bericht als **Jupyter Notebook als Colab Link** und
# *   als **.ipynb File** per eMail an daniel.benninger@hslu.ch.
#
#
# Alternativ kann, anstelle des Colab Links auch der Link auf eine Github Ablage (Repository) zugestellt werden. Achtung: bei privaten Repositories bitte mir den Zugriff ebenfalls ermöglichen!
#
# **Dokumentation und Erarbeitung**
#
# Jupyter/Notebook: Dokumentieren und erarbeiten Sie Ihre Case
#
# Study als Jupyter Notebook. Dies ermöglicht eine interaktive und nachvollziehbare Darstellung Ihrer Analyse und Ergebnisse.
#
# Inhalte: Stellen Sie sicher, dass Ihr Notebook folgende Aspekte beinhaltet:
#
# *   **Einleitung**: Kurze Vorstellung des gewählten Kontexts und der Zielsetzung.
#
# *   **Ziele und Informationsbedarf**: Definition der spezifischen Ziele Ihrer Case Study und des Informationsbedarfs zur Erreichung dieser Ziele.
#
# *   **Datensammlung und -beschaffung:** Beschreibung, wie und woher die Daten gesammelt wurden.
#
# *   **Datenanalyse**: Darstellung der Analysemethoden und -werkzeuge, die verwendet wurden, um Einsichten aus den Daten zu gewinnen.
#
# *   **Präsentation der Ergebnisse**: Visualisierung und Interpretation der Analyseergebnisse, die zu den Entscheidungen geführt haben.
#
#
# Durch die sorgfältige Planung und Zusammenarbeit innerhalb Ihrer Gruppe können Sie eine fundierte und überzeugende Case Study erstellen, die die kritischen Schritte von der Datensammlung bis zur Entscheidungsfindung erfolgreich demonstriert.
#
# **Bewertung und Gewichtung**:
#
#     Ziele und Informationsbedarf (20%)
#     Datensammlung, -beschaffung (10%)
#     Datenanalyse (40%)
#     Präsentation der Ergebnisse (30%)
# ---

# %% [markdown]
# **Quellen**
#
#
# https://www.energie-experten.ch/de/detail/die-kernelemente-der-energiestrategie-2050.html
#
# https://www.bafu.admin.ch/bafu/de/home/themen/klima/inkuerze.html
#
# https://www.meteoschweiz.admin.ch/klima/klimawandel/globaler-klimawandel-aktueller-wissensstand/klimaziele.html

# %% [markdown]
# ---

# %% [markdown]
# # Einleitung

# %% [markdown]
# In einer Welt, wo die von technologischem Fortschritt und wirtschaftlicher Entwicklung geprägt ist, spielt Energie eine zentrale Rolle. Sie ist ein unverzichtbares Element für die Industrie, Transportwesen, Dienstleistungen, Landwirtschaft und für das tägliche Leben. Doch während die Nachfrage nach Energie stetig steigt, sind wir uns zunehmend bewusst geworden, dass ihre Nutzung gravierende Auswirkungen auf die Umwelt und das Klima hat.
#
# Die Schweiz, ein Land mit einer florierenden Wirtschaft und einer hohen Lebensqualität, ist keine Ausnahme in dieser globalen Dynamik. Derzeit gelten die globalen Klimaziele zur Begrenzung des globalen Temperaturanstiegs deutlich unter 2 Grad Celsius, die im Übereinkommen von Paris verabschiedet wurden. Auch die Schweiz hat dieses Übereinkommen ratifiziert. Konkret bedeutet dies für die Schweiz, dass sie die Treibhausgasemission reduzieren auf die zweite Hälfte des Jahrhunderts «Netto-Null» erreichen muss. Dabei bedeutet «Netto-Null» Emissionen, dass zukünftig keine Treibhausgase mehr in die Atmosphäre kommen dürfen. Mit der Ratifizierung des Pariser Übereinkommens hat sich die Schweiz verpflichtet die Treibhausgasemissionen um 50% gegenüber 1990 zu reduzieren. Die Schweiz setzt dies mit dem CO2-Gesetz um. Der Grossteil der Treibhausgasemission fällt durch den Verkehr (30,6%), die Industrie (23,6%, die Haushalte (17,6%), der Landwirtschaft (14,3%) und den Dienstleistungssektor (8,2%) an. Im Rahmen der langfristigen Schweizer Klimastrategie wird bis 2050 angestrebt die Treibhausgase auf Netto-Null zu reduzieren. (Quelle: Meteoschweiz.admin.ch). Leider können mit dieser Strategie die negativen Umweltauswirkungen nicht vollständig verhindert, jedoch können diese abgeschwächt werden.Seit den 1980er Jahren hat die Schweiz eine Reihe von Maßnahmen ergriffen, um ihren Energieverbrauch zu steuern, die Energieeffizienz zu verbessern und die Treibhausgasemissionen zu reduzieren. Diese Bemühungen wurden durch verschiedene politische, wirtschaftliche und technologische Entwicklungen beeinflusst und geprägt. Bei dieser Arbeit wird die Schweizer Klima- und Energiepolitik in Bezug des Klimaindikators untersucht. Im Rahmen der Klima- und Energiepolitik werden nachfolgende Massnahmen verfolgt.
#
# *   Ausbau erneuerbare Energien
# *   Ausstieg aus der Kernenergie
# *   Steigerung der Energieeffizienz

# %% [markdown]
# # 1. Definition Ziele und Festlegung der Daten

# %% [markdown]
# ## 1.1 Definition der Ziele

# %% [markdown]
# Das primäre Ziel dieser Arbeit ist es, anhand von Daten zu analysieren, wie sich der Energiekonsum sowie die Energieproduktion in der Schweiz in Bezug der Netto-Null-Ziele 2050 entwickelt hat. Der Fokus liegt auf dem Klimaindikator der Schweizer Energie- und Klimapolitik, dabei wurde die Zielsetzung in drei zentrale Fragestellungen eingeteilt:
#
# 1. Wie hat sich der gesamte Energieverbrauch der Energieträger, Sektoren und pro Kopf entwickelt?
#
# Hier soll untersucht werden, wie sich der gesamte Energieverbrauch in den Sektoren Industrie, Dienstleistungen, Landwirtschaft, Transport und Haushalte entwickelt hat und wie die momentane Verteilung ist.
#
#
# 2. Wie hat sich die Stromproduktion in der Schweiz in Bezug der erneuerbaren und nicht erneuerbaren Energien entwickelt?
#
# Hier soll ermittelt werden, wie sich der Einsatz der Energieträger hinsichtlich erneuerbarer und nicht erneuerbarer Energie entwickelt hat. Bei diesem Ziel soll analysiert werden, welche Trends sich in Bezug Kernenergie abzeichnet und ob ein Ausstieg zu erkennen ist.
#
#
# 3. Wie hat sich die Energieeffizienz entwickelt?
#
# Mit dieser Zielsetzung soll beobachtet werden, wie die die Energieeffizienz in Bezug des Bruttoinlandprodukts, der Bevölkerung aber auch der Sektoren entwickelt hat.

# %% [markdown]
# ## 1.2 Vorgehen

# %% [markdown]
# Im Rahmen dieser Arbeit wird nach dem fünfstufigen Modell des Chartered Professional Accountants (CPA) "From Data to Decision" vorgegangen (siehe Abbildung 1). Der letzte Schritt wird in dieser Arbeit nicht behandelt:

# %% [markdown]
# ![CPA.PNG](data:image/png;base64,...)

# %% [markdown]
# Abbildung 1: CPA Management Accounting Guideline (Quelle: CPA 2021)

# %% [markdown]
# **1. Ziele und Informationsbedarf definieren**
#
# Im Rahmen des ersten Schrittes werden die Ziele und Informationsbedürfnisse festegelegt. Dabei werden die Fragen beantwortet, was sind die strategischen Ziele sind und was genau auf der Basis dieser Ziele bekannt sein muss?
#
# **2. Daten sammeln**
#
# Im zweiten Schritt gilt es die definierten Daten und Informationen zu sammeln und zu organisieren. Ziel dabei ist, sicherzustellen, dass die gesammelten Daten mit im ersten Schritt festegelegten Ziele mit den gefundenen Daten erreicht werden können.
#
# **3. Daten analysieren und visualisieren**
#
# Beim Schritt 3 werden die gewonnen Daten analysiert, um aus den analysierten Daten Informationen extrahieren zu können. Dieser Schritt umfasst dabei die Analyse sämtliche Daten, um alle definierten Fragen und Teilfragestellungen beantworten zu können.
#
# **4. Daten präsentieren**
#
# Im Schritt 4 werden die Daten aufbereitet und präsentiert. Dazu werden Slides erarbeitet, welche die Ergebnisse der Analyse präsentieren.

# %% [markdown]
# ## 1.3 Festlegung der Daten

# %% [markdown]
# Um die oben definierten Fragestellungen beantworten zu können, benötigt die Projektgruppe die nachfolgenden Datenquellen und -sätze.
#
# Sektoren, Bevölkerung und Wirtschaft
#
# - Verbrauch total pro Jahr in Terajoule
# - Verbrauch Dienstleistungen pro Jahr in Terajoule
# - Verbrauch Haushalte pro Jahr in Terajoule
# - Verbrauch Industrie pro Jahr in Terajoule
# - Verbrauch stat. Differenz inkl. Landwirtschaft pro Jahr in Terajoule
# - Energiekonsum (gesamt, pro Kopf) in Terajoule
# - Bruttoinlandprodukt in USD
# - Bruttoinlandprodukt pro Kopf in USD
#
# Sekundärenergie für Nutzung
#
# - Verbrauch erneuerbarer und nicht-erneuerbarer Energie pro Jahr in TJ
# - Verbrauch Elektrizität pro Jahr in Terajoule
# - Verbrauch Erdölprodukte pro Jahr in Terajoule
# - Verbrauch Fernwärme pro Jahr in Terajoule
# - Verbrauch Gas pro Jahr in Terajoule
# - Verbrauch Holzenergie pro Jahr in Terajoule
# - Verbrauch Kohle pro Jahr in Terajoule
# - Verbrauch Müll und Industrieabfälle pro Jahr in Terajoule
# - Verbrauch übrige erneuerbare Energien pro Jahr in Terajoule
#
# Primärenergie für Stromproduktion
#
# - Umwandlung Kernenergie pro Jahr in TJ
# - Umwandlung Wasserkraft pro Jahr in TJ
# - Umwandlung weitere erneuerbare Energien pro Jahr in TJ
#
# CO2 Ausstoss
# - CO2 Ausstoss der Bereiche Gebäude, Verkehr, Industrie und Übrige

# %% [markdown]
# # 2. Daten sammeln

# %% [markdown]
# Basierend auf der CPA Management Accounting Guideline «Collecting Data» besteht in diesem Kapital die Zielsetzung, die korrekten Daten zu gewinnen und zu organisieren. Wichtig hier ist, dass sinnvolle und relevante Daten gefunden werden, damit die in Kapital 1 definierten Daten und Zielsetzung sichergestellt werden können. In Anlehnung an die CPA Management Accounting Guideline können für die Datenbeschaffung bereits verfügbare Daten verwendet werden oder die relevanten Daten müsssen erhoben werden.

# %% [markdown]
# ## 3.1 Datenquellen

# %% [markdown]
# Um die notwendigen Daten zu beschaffen und sammeln, wurden die nachfolgenden Datenquellen konsultiert.
#
# - Weltbank
# - Bundesamt für Statistik [BFS]
# - Bundesamt für Energie [BAFU]
#
#
# Die Daten wurden in Form von CSV-Dateien mit Semikolon als Trennzeichen bezogen. Diese Rohdaten sind auf dem nachfolgenden GitHub Repository hinterlegt:
#
#
# https://raw.githubusercontent.com/michaelzimmermannstudhslu/BINA_2024_energy_research/main/data/bip_total.csv'
#
# https://raw.githubusercontent.com/michaelzimmermannstudhslu/BINA_2024_energy_research/main/data/energiebilanz_ch.csv
#
# https://raw.githubusercontent.com/michaelzimmermannstudhslu/BINA_2024_energy_research/main/data/co2.csv

# %% [markdown]
# Beschreibung Entscheidung für Datenquelle...
# ...
# ...
# ...
# ...

# %% [markdown]
# ## 3.1 Daten importieren, aufbereiten und organisieren

# %% [markdown]
# ### 3.1.1 Daten importieren

# %% [markdown]
# Der Datenimport via GitHub Reporsitory und die entsprechende Datenverarbeitung erfolgt mit der Python-Bibliothek «pandas». Um dies zu ermöglichen, muss die pandas Bibliothek importiert werden.

# %%
import pandas as pd
from pandas_schema import Column, Schema
from pandas_schema.validation import CanConvertValidation, InRangeValidation, InListValidation

# %% [markdown]
# Um die Rohdaten zu überprüfen, werden die Überschriften, Formate, die ersten fünf sowie die letzten fünf Datensätze geladen.

# %% [markdown]
# **Energiedaten**

# %%
# Rohdaten im CSV-Format importieren und abspeichern in Dataframe

Energiedaten = pd.read_csv('https://raw.githubusercontent.com/michaelzimmermannstudhslu/BINA_2024_energy_research/main/data/energiebilanz_ch.csv')

# Kontrolle Struktur der Daten durchführen

Energiedaten.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8987 entries, 0 to 8986
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Jahr            8987 non-null   int64
#  1   Rubrik          8987 non-null   object
#  2   Energietraeger  8987 non-null   object
#  3   TJ              8987 non-null   object
# dtypes: int64(1), object(3)
# memory usage: 281.0+ KB

# %%
# Erste fünf Datensätze zeigen

Energiedaten.head()
# Out:
#    Jahr           Rubrik Energietraeger      TJ
# 0  1980  Bruttoverbrauch   Elektrizität  -29450
# 1  1980  Bruttoverbrauch  Erdölprodukte  321250
# 2  1980  Bruttoverbrauch      Fernwärme       0
# 3  1980  Bruttoverbrauch            Gas   36280
# 4  1980  Bruttoverbrauch    Holzenergie   26280

# %%
# Letze fünf Datensätze zeigen

Energiedaten.tail()
# Out:
#       Jahr                        Rubrik                Energietraeger  \
# 8982  2022  Nichtenergetischer Verbrauch                         Kohle
# 8983  2022  Nichtenergetischer Verbrauch     Müll und Industrieabfälle
# 8984  2022  Nichtenergetischer Verbrauch                         Rohöl
# 8985  2022  Nichtenergetischer Verbrauch  Uebrige erneuerbare Energien
# 8986  2022  Nichtenergetischer Verbrauch                   Wasserkraft
#
#                          TJ
# 8982  keine Daten verfügbar
# 8983  keine Daten verfügbar
# 8984  keine Daten verfügbar
# 8985  keine Daten verfügbar
# 8986  keine Daten verfügbar

# %%
# Alle Rubriken zeigen
print(Energiedaten['Rubrik'].unique())
# Out:
# ['Bruttoverbrauch'
#  'Eigenverbrauch des Energiesektors, Netzverluste, Verbrauch der Speicherungen'
#  'Endverbrauch - Dienstleistungen' 'Endverbrauch - Haushalte'
#  'Endverbrauch - Industrie'
#  'Endverbrauch - Statistische Differenz inkl. Landwirtschaft'
#  'Endverbrauch - Total' 'Endverbrauch - Verkehr'
#  'Energieumwandlung - Diverse Erneuerbare' 'Energieumwandlung - Gaswerke'
#  'Energieumwandlung - Kernkraftwerke' 'Energieumwandlung - Raffinerien'
#  'Energieumwandlung - Wasserkraftwerke'
#  'Energieumwandlung - konventionell-thermische Kraft-, Fernheiz- und Fernheizkraftwerke'
#  'Export' 'Import' 'Inlandproduktion' 'Lagerveränderung'
#  'Nichtenergetischer Verbrauch']

# %%
print(Energiedaten['Energietraeger'].unique())
# Out:
# ['Elektrizität' 'Erdölprodukte' 'Fernwärme' 'Gas' 'Holzenergie'
#  'Kernbrennstoffe' 'Kohle' 'Müll und Industrieabfälle' 'Rohöl'
#  'Wasserkraft' 'Uebrige erneuerbare Energien']

# %%
print(Energiedaten['Jahr'].unique())
# Out:
# [1980 1981 1982 1983 1984 1985 1986 1987 1988 1989 1990 1991 1992 1993
#  1994 1995 1996 1997 1998 1999 2000 2001 2002 2003 2004 2005 2006 2007
#  2008 2009 2010 2011 2012 2013 2014 2015 2016 2017 2018 2019 2020 2021
#  2022]

# %% [markdown]
# Die Energiedaten wurden erfolgreich geladen.

# %% [markdown]
# **Daten Bevölkerung und Bruttoinlandprodukt**

# %% [markdown]
# Um die Rohdaten zu überprüfen, werden die Überschriften, Formate, die ersten fünf sowie die letzten fünf Datensätze geladen.

# %%
#Code von Michi
#Inflationsrate entfernen
#Erste und letzte fünf Zeilen der Ausgabe anzeigen
#Daten Bevölkerung und Bruttoinlandprodukt importieren und in Dataframes zur weiteren Verwendung abspeichern.

BevoelkerungBIP = pd.read_csv('https://raw.githubusercontent.com/michaelzimmermannstudhslu/BINA_2024_energy_research/main/data/bip_total.csv')

BevoelkerungBIP.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44 entries, 0 to 43
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Jahr            43 non-null     float64
#  1   Bevölkerung     43 non-null     float64
#  2   BIP             43 non-null     float64
#  3   Inflationsrate  44 non-null     float64
# dtypes: float64(4)
# memory usage: 1.5 KB

# %%
BevoelkerungBIP.head()
# Out:
#      Jahr  Bevölkerung        BIP  Inflationsrate
# 0  1980.0    6335243.0  205370.18             4.0
# 1  1981.0    6372904.0  220471.25             6.5
# 2  1982.0    6409713.0  233572.55             5.7
# 3  1983.0    6427833.0  240628.98             2.9
# 4  1984.0    6455896.0  257187.15             2.9

# %%
BevoelkerungBIP.tail()
# Out:
#       Jahr  Bevölkerung        BIP  Inflationsrate
# 39  2019.0    8606033.0  716878.59             0.4
# 40  2020.0    8670300.0  696619.96            -0.7
# 41  2021.0    8738791.0  743330.23             0.6
# 42  2022.0    8815385.0  781460.27             2.8
# 43     NaN          NaN        NaN             2.1

# %%
print(BevoelkerungBIP['Jahr'].unique())
# Out:
# [1980. 1981. 1982. 1983. 1984. 1985. 1986. 1987. 1988. 1989. 1990. 1991.
#  1992. 1993. 1994. 1995. 1996. 1997. 1998. 1999. 2000. 2001. 2002. 2003.
#  2004. 2005. 2006. 2007. 2008. 2009. 2010. 2011. 2012. 2013. 2014. 2015.
#  2016. 2017. 2018. 2019. 2020. 2021. 2022.   nan]

# %% [markdown]
# Die Daten der Bevölkerung des Bruttoinlandprodukts wurden erfolgreich geladen. Da die Daten als Kommazahl dargestellt sind müssen in eine ganze Zahl formatiert werden.

# %% [markdown]
# **Daten CO2 Ausstoss**

# %%
#Code von Michi
#Erste und letzte fünf Zeilen der Ausgabe anzeigen
#Daten CO2 Ausstoss importieren und in Dataframes zur weiteren Verwendung abspeichern.

CO2Ausstoss = pd.read_csv('https://raw.githubusercontent.com/michaelzimmermannstudhslu/BINA_2024_energy_research/main/data/co2.csv')

CO2Ausstoss.head()
# Out:
#    Jahr    THG
# 0  1990  55.34
# 1  1991  57.22
# 2  1992  56.94
# 3  1993  54.33
# 4  1994  53.26

# %%
CO2Ausstoss.tail()
# Out:
#     Jahr    THG
# 27  2017  48.37
# 28  2018  46.86
# 29  2019  46.59
# 30  2020  43.91
# 31  2021  45.25

# %%
print(CO2Ausstoss['Jahr'].unique())
# Out:
# [1990 1991 1992 1993 1994 1995 1996 1997 1998 1999 2000 2001 2002 2003
#  2004 2005 2006 2007 2008 2009 2010 2011 2012 2013 2014 2015 2016 2017
#  2018 2019 2020 2021]

# %% [markdown]
# ### 3.1.2 Daten aufbereiten

# %% [markdown]
# Folgendes kann gemacht werden:
#
# *   Unnötige Zeilen, Werte entfernen
# *   Float zu Int umwandeln
# *   Überschriften ändern
# *   etc.

# %%
# Erlaubte Werte für 'Rubrik' definieren
allowed_rubriken = [
    'Bruttoverbrauch',
    'Eigenverbrauch des Energiesektors, Netzverluste, Verbrauch der Speicherungen',
    'Endverbrauch - Dienstleistungen', 'Endverbrauch - Haushalte',
    'Endverbrauch - Industrie',
    'Endverbrauch - Statistische Differenz inkl. Landwirtschaft',
    'Endverbrauch - Total', 'Endverbrauch - Verkehr',
    'Energieumwandlung - Diverse Erneuerbare', 'Energieumwandlung - Gaswerke',
    'Energieumwandlung - Kernkraftwerke', 'Energieumwandlung - Raffinerien',
    'Energieumwandlung - Wasserkraftwerke',
    'Energieumwandlung - konventionell-thermische Kraft-, Fernheiz- und Fernheizkraftwerke',
    'Export', 'Import', 'Inlandproduktion', 'Lagerveränderung',
    'Nichtenergetischer Verbrauch'
]

# Erlaubte Werte für 'Energietraeger' definieren
renewable_energietraeger = [
    'Wasserkraft', 'Uebrige erneuerbare Energien', 'Holzenergie'
]

# Erlaubte Werte für 'Energietraeger' definieren
non_renewable_energietraeger = [
    'Elektrizität', 'Erdölprodukte', 'Fernwärme', 'Gas',
    'Kernbrennstoffe', 'Kohle', 'Müll und Industrieabfälle', 'Rohöl'
]

# Schema als Konstante definieren
BIP_SCHEMA = Schema([
    Column('Jahr', [CanConvertValidation(int), InRangeValidation(1980, 2024)]),
    Column('Bevölkerung', [CanConvertValidation(int), InRangeValidation(0, 1000000000)]),
    Column('BIP', [CanConvertValidation(float), InRangeValidation(0, float('inf'))]),
    Column('Bip_pro_Kopf', [CanConvertValidation(float), InRangeValidation(0, float('inf'))])
])

# Schema für das Energy DataFrame als Konstante definieren
ENERGY_SCHEMA = Schema([
    Column('Jahr', [CanConvertValidation(int), InRangeValidation(1980, 2024)]),  # Validiere, dass 'Jahr' ein Integer im spezifizierten Bereich ist
    Column('Rubrik', [CanConvertValidation(str), InListValidation(allowed_rubriken)]),  # Stelle sicher, dass 'Rubrik' ein String ist
    Column('Energietraeger', [CanConvertValidation(str), InListValidation(renewable_energietraeger + non_renewable_energietraeger)]),  # Stelle sicher, dass 'Energietraeger' ein String ist
    Column('TJ', [CanConvertValidation(float)])  # Stelle sicher, dass 'TJ' ein nicht-negativer Float ist
])

# Define the schema for CO2 emissions data as a constant
CO2_SCHEMA = Schema([
    Column('Jahr', [
        CanConvertValidation(int),  # Ensure 'Jahr' can be converted to an integer
        InRangeValidation(1980, 2024)  # Validate that 'Jahr' is within the 20th and 21st centuries
    ]),
    Column('THG', [
        CanConvertValidation(float)
    ])
])

def validate_and_clean_dataframe(df, schema):
    """
    Entfernt Spalten aus dem DataFrame, die nicht im Schema definiert sind.

    Parameters:
    - df (pd.DataFrame): Der zu validierende DataFrame.
    - schema (Schema): Das Schema, gegen das der DataFrame validiert wird.

    Returns:
    - df (pd.DataFrame): Der bereinigte DataFrame, der nur die im Schema definierten Spalten enthält.
    """
    # Extrahiere Spaltennamen aus dem Schema
    schema_columns = [column.name for column in schema.columns]

    # Entferne Spalten, die nicht im Schema definiert sind
    df = df.loc[:, schema_columns]
    return df

def validate_dataframe(df: pd.DataFrame, schema: Schema):
    """
    Validiert einen DataFrame gegen ein bereitgestelltes Schema und wirft eine Ausnahme, wenn Validierungsfehler gefunden werden.

    Parameters:
    - df (pd.DataFrame): Der zu validierende DataFrame.
    - schema (Schema): Das Schema, gegen das der DataFrame validiert wird.

    Raises:
    - ValueError: Wenn im DataFrame Validierungsfehler gefunden werden.

    Returns:
    - None
    """
    # Validiere den DataFrame mit dem bereitgestellten Schema
    errors = schema.validate(df)
    if errors:
        # Sammle alle Fehlermeldungen in einem einzigen String
        error_messages = "\n".join(str(e) for e in errors)
        # Drucke Fehler zur Protokollierung
        print(f"Validation errors occurred:\n{error_messages}")
        # Wirf eine Ausnahme mit allen Fehlermeldungen
        raise ValueError(f"Validation errors occurred:\n{error_messages}")
    else:
        print("Alle Daten sind gültig.")

# %%
# Vorverarbeitung und Datentypkonvertierung
Energiedaten['Jahr'] = pd.to_numeric(Energiedaten['Jahr'], errors='coerce').fillna(0).astype(int)
Energiedaten['TJ'] = pd.to_numeric(Energiedaten['TJ'], errors='coerce').fillna(0).astype(int)
Energiedaten['Rubrik'] = Energiedaten['Rubrik'].str.replace('–', '-', regex=False)
Energiedaten.dropna(inplace=True)  # Entferne Zeilen mit fehlenden Werten

Energiedaten = validate_and_clean_dataframe(Energiedaten, ENERGY_SCHEMA)

validate_dataframe(Energiedaten, ENERGY_SCHEMA)

print(Energiedaten)
# Out:
# Alle Daten sind gültig.
#       Jahr                        Rubrik                Energietraeger      TJ
# 0     1980               Bruttoverbrauch                  Elektrizität  -29450
# 1     1980               Bruttoverbrauch                 Erdölprodukte  321250
# 2     1980               Bruttoverbrauch                     Fernwärme       0
# 3     1980               Bruttoverbrauch                           Gas   36280
# 4     1980               Bruttoverbrauch                   Holzenergie   26280
# ...    ...                           ...                           ...     ...
# 8982  2022  Nichtenergetischer Verbrauch                         Kohle       0
# 8983  2022  Nichtenergetischer Verbrauch     Müll und Industrieabfälle       0
# 8984  2022  Nichtenergetischer Verbrauch                         Rohöl       0
# 8985  2022  Nichtenergetischer Verbrauch  Uebrige erneuerbare Energien       0
# 8986  2022  Nichtenergetischer Verbrauch                   Wasserkraft       0
#
# [8987 rows x 4 columns]

# %%
# Vorverarbeitung und Datentypkonvertierung
BevoelkerungBIP.dropna(inplace=True)  # Entferne Zeilen mit fehlenden Werten
BevoelkerungBIP['Bevölkerung'] = pd.to_numeric(BevoelkerungBIP['Bevölkerung'], errors='coerce').fillna(0).astype(int)
BevoelkerungBIP['Jahr'] = pd.to_numeric(BevoelkerungBIP['Jahr'], errors='coerce').fillna(0).astype(int)

# Berechnung von 'Bip_pro_Kopf' vor der Validierung
BevoelkerungBIP['Bip_pro_Kopf'] = (BevoelkerungBIP['BIP'] / BevoelkerungBIP['Bevölkerung']) * 100

BevoelkerungBIP = validate_and_clean_dataframe(BevoelkerungBIP, BIP_SCHEMA)

# Validiere das DataFrame
validate_dataframe(BevoelkerungBIP, BIP_SCHEMA)

print(BevoelkerungBIP)
# Out:
# Alle Daten sind gültig.
#     Jahr  Bevölkerung        BIP  Bip_pro_Kopf
# 0   1980      6335243  205370.18      3.241710
# 1   1981      6372904  220471.25      3.459510
# 2   1982      6409713  233572.55      3.644041
# 3   1983      6427833  240628.98      3.743547
# 4   1984      6455896  257187.15      3.983756
# 5   1985      6484834  272689.73      4.205038
# 6   1986      6523413  286186.86      4.387073
# 7   1987      6566799  297101.28      4.524294
# 8   1988      6619973  315400.60      4.764379
# 9   1989      6673850  340440.35      5.101109
# 10  1990      6750693  369198.76      5.469050
# 11  1991      6842768  385605.03      5.635220
# 12  1992      6907959  393625.51      5.698145
# 13  1993      6968570  402258.17      5.772464
# 14  1994      7019019  412190.66      5.872482
# 15  1995      7062354  417228.34      5.907780
# 16  1996      7081346  420368.49      5.936279
# 17  1997      7096465  427826.11      6.028721
# 18  1998      7123537  439954.88      6.176073
# 19  1999      7164444  447465.79      6.245646
# 20  2000      7204055  471540.04      6.545481
# 21  2001      7255653  483636.92      6.665657
# 22  2002      7313853  482077.20      6.591289
# 23  2003      7364148  487606.52      6.621357
# 24  2004      7415102  502265.68      6.773551
# 25  2005      7459128  520848.32      6.982697
# 26  2006      7508739  553721.55      7.374361
# 27  2007      7593494  589085.16      7.757762
# 28  2008      7701856  614407.72      7.977398
# 29  2009      7785806  603039.07      7.745365
# 30  2010      7864012  624545.12      7.941813
# 31  2011      7954662  635738.74      7.992027
# 32  2012      8039060  643645.59      8.006478
# 33  2013      8139631  654611.67      8.042277
# 34  2014      8237666  665618.37      8.080182
# 35  2015      8327126  668006.38      8.022052
# 36  2016      8419550  677848.33      8.050885
# 37  2017      8484130  684558.47      8.068694
# 38  2018      8544527  709521.56      8.303813
# 39  2019      8606033  716878.59      8.329954
# 40  2020      8670300  696619.96      8.034554
# 41  2021      8738791  743330.23      8.506099
# 42  2022      8815385  781460.27      8.864732

# %%
# Vorverarbeitung und Datentypkonvertierung
CO2Ausstoss['Jahr'] = pd.to_numeric(CO2Ausstoss['Jahr'], errors='coerce').fillna(0).astype(int)
CO2Ausstoss.dropna(inplace=True)  # Entferne Zeilen mit fehlenden Werten

CO2Ausstoss = validate_and_clean_dataframe(CO2Ausstoss, CO2_SCHEMA)

# Validiere das DataFrame
validate_dataframe(CO2Ausstoss, CO2_SCHEMA)

print(CO2Ausstoss)
# Out:
# Alle Daten sind gültig.
#     Jahr    THG
# 0   1990  55.34
# 1   1991  57.22
# 2   1992  56.94
# 3   1993  54.33
# 4   1994  53.26
# 5   1995  54.13
# 6   1996  54.76
# 7   1997  53.53
# 8   1998  55.04
# 9   1999  54.83
# 10  2000  54.07
# 11  2001  55.58
# 12  2002  54.01
# 13  2003  55.06
# 14  2004  55.64
# 15  2005  56.25
# 16  2006  55.92
# 17  2007  53.98
# 18  2008  55.36
# 19  2009  53.87
# 20  2010  55.46
# 21  2011  51.33
# 22  2012  52.66
# 23  2013  53.49
# 24  2014  49.55
# 25  2015  49.03
# 26  2016  49.34
# 27  2017  48.37
# 28  2018  46.86
# 29  2019  46.59
# 30  2020  43.91
# 31  2021  45.25

# %% [markdown]
# ### 3.1.3 Daten organisieren

# %% [markdown]
# Daten zu sinnvollen Datasets zusammenfügen?
#
# *   BevölkerungsEntwicklung
# *   BIPEntwicklung
# *   SektorenEntwicklung
# *   C02Ausstoss

# %%
def summarize_energy_data_per_year_per_column(df, category_column):
    """
    Summiert Energieverbrauchsdaten nach Jahr und einer spezifizierten Kategorie und berechnet die Prozentsätze jeder Kategorie.

    Parameters:
    df (pd.DataFrame): Der DataFrame, der die Energieverbrauchsdaten enthält.
    category_column (str): Der Name der Spalte, die die Kategorien beschreibt, nach denen summiert wird.

    Returns:
    pd.DataFrame: Ein DataFrame mit den summierten Daten und den berechneten Prozentsätzen für jede Kategorie.
    """
    # Gruppiere Daten nach Jahr und der spezifizierten Kategorie, und summiere die Energieverbrauchsdaten ('TJ') für jede Gruppe
    category_data_summed_per_year = df.groupby(['Jahr', category_column])['TJ'].sum().reset_index()

    # Gruppiere Daten nur nach Jahr und summiere die gesamte Energie ('TJ') für jedes Jahr
    total_energy_per_year = df.groupby('Jahr')['TJ'].sum().reset_index()
    total_energy_per_year.rename(columns={'TJ': 'TotalEnergy'}, inplace=True)  # Benenne die Spalte 'TJ' um in 'TotalEnergy'

    # Führe die Daten zu summierten Kategorien mit den totalen Energie-Daten zusammen, basierend auf dem Jahr
    summarized_data = pd.merge(category_data_summed_per_year, total_energy_per_year, on='Jahr')

    # Berechne den Prozentsatz des Verbrauchs jeder Kategorie relativ zur gesamten Energieverbrauchsmenge des jeweiligen Jahres
    summarized_data['Percentage'] = (summarized_data['TJ'] / summarized_data['TotalEnergy']) * 100

    return summarized_data

# %%
EnergiedatenEndverbrauch = Energiedaten[Energiedaten['Rubrik'] == 'Endverbrauch - Total']

EnergieDatenEndverbrauchSummiert = summarize_energy_data_per_year_per_column(EnergiedatenEndverbrauch, 'Energietraeger')

print(EnergieDatenEndverbrauchSummiert)
# Out:
#      Jahr                Energietraeger      TJ  TotalEnergy  Percentage
# 0    1980                  Elektrizität  126910       698290   18.174397
# 1    1980                 Erdölprodukte  489480       698290   70.096951
# 2    1980                     Fernwärme    7920       698290    1.134199
# 3    1980                           Gas   30370       698290    4.349196
# 4    1980                   Holzenergie   26280       698290    3.763479
# ..    ...                           ...     ...          ...         ...
# 468  2022                         Kohle    3850       765070    0.503222
# 469  2022     Müll und Industrieabfälle   12280       765070    1.605082
# 470  2022                         Rohöl       0       765070    0.000000
# 471  2022  Uebrige erneuerbare Energien   32260       765070    4.216608
# 472  2022                   Wasserkraft       0       765070    0.000000
#
# [473 rows x 5 columns]

# %%
# Apply correct filtering for specific categories
EnergiedatenSektoren = Energiedaten[(Energiedaten['Rubrik'] == 'Endverbrauch - Haushalte') |
        (Energiedaten['Rubrik'] == 'Endverbrauch - Dienstleistungen') |
        (Energiedaten['Rubrik'] == 'Endverbrauch - Industrie') |
        (Energiedaten['Rubrik'] == 'Endverbrauch - Statistische Differenz inkl. Landwirtschaft') |
        (Energiedaten['Rubrik'] == 'Endverbrauch - Verkehr')]

EnergieDatenSektorenSummiert = summarize_energy_data_per_year_per_column(EnergiedatenSektoren, 'Rubrik')

print(EnergieDatenSektorenSummiert)
# Out:
#      Jahr                                             Rubrik      TJ  \
# 0    1980                    Endverbrauch - Dienstleistungen  117700
# 1    1980                           Endverbrauch - Haushalte  242310
# 2    1980                           Endverbrauch - Industrie  144200
# 3    1980  Endverbrauch - Statistische Differenz inkl. La...    7380
# 4    1980                             Endverbrauch - Verkehr  186700
# ..    ...                                                ...     ...
# 210  2022                    Endverbrauch - Dienstleistungen  122510
# 211  2022                           Endverbrauch - Haushalte  211310
# 212  2022                           Endverbrauch - Industrie  145550
# 213  2022  Endverbrauch - Statistische Differenz inkl. La...    8890
# 214  2022                             Endverbrauch - Verkehr  276810
#
#      TotalEnergy  Percentage
# 0         698290   16.855461
# 1         698290   34.700483
# 2         698290   20.650446
# 3         698290    1.056867
# 4         698290   26.736743
# ..           ...         ...
# 210       765070   16.012914
# 211       765070   27.619695
# 212       765070   19.024403
# 213       765070    1.161985
# 214       765070   36.181003
#
# [215 rows x 5 columns]

# %%
# Apply correct filtering for specific categories
EnergiedatenInlandImport = Energiedaten[(Energiedaten['Rubrik'] == 'Import') | (Energiedaten['Rubrik'] == 'Inlandproduktion')]

EnergiedatenInlandImport = summarize_energy_data_per_year_per_column(EnergiedatenInlandImport, 'Energietraeger')

print(EnergiedatenInlandImport)
# Out:
#      Jahr                Energietraeger      TJ  TotalEnergy  Percentage
# 0    1980                  Elektrizität   35810       932010    3.842233
# 1    1980                 Erdölprodukte  338250       932010   36.292529
# 2    1980                     Fernwärme       0       932010    0.000000
# 3    1980                           Gas   36860       932010    3.954893
# 4    1980                   Holzenergie   26280       932010    2.819712
# ..    ...                           ...     ...          ...         ...
# 468  2022                         Kohle    3870      1139580    0.339599
# 469  2022     Müll und Industrieabfälle   58540      1139580    5.136980
# 470  2022                         Rohöl  133310      1139580   11.698170
# 471  2022  Uebrige erneuerbare Energien   50920      1139580    4.468313
# 472  2022                   Wasserkraft  120600      1139580   10.582846
#
# [473 rows x 5 columns]

# %%
renewableEnergydataInlandImport = summarize_energy_data_per_year_per_column(EnergiedatenInlandImport[EnergiedatenInlandImport['Energietraeger'].isin(renewable_energietraeger)], 'Energietraeger')

print(renewableEnergydataInlandImport)
# Out:
#      Jahr                Energietraeger      TJ  TotalEnergy  Percentage
# 0    1980                   Holzenergie   26280       147030   17.873903
# 1    1980  Uebrige erneuerbare Energien       0       147030    0.000000
# 2    1980                   Wasserkraft  120750       147030   82.126097
# 3    1981                   Holzenergie   25480       155430   16.393232
# 4    1981  Uebrige erneuerbare Energien       0       155430    0.000000
# ..    ...                           ...     ...          ...         ...
# 124  2021  Uebrige erneuerbare Energien   47860       243160   19.682514
# 125  2021                   Wasserkraft  142200       243160   58.480013
# 126  2022                   Holzenergie   47820       219340   21.801769
# 127  2022  Uebrige erneuerbare Energien   50920       219340   23.215100
# 128  2022                   Wasserkraft  120600       219340   54.983131
#
# [129 rows x 5 columns]

# %%
# Pivot the data for plotting
percentage_pivoted_data = EnergieDatenEndverbrauchSummiert.pivot_table(index='Jahr', columns='Energietraeger', values='Percentage', fill_value=0)

# %%
# Pivot the data for plotting
totalEnergy_pivoted_data = EnergieDatenEndverbrauchSummiert.pivot_table(index='Jahr', columns='Energietraeger', values='TJ', fill_value=0)

# %%
# Pivot the data for plotting
totalSector_pivoted_data = EnergieDatenSektorenSummiert.pivot_table(index='Jahr', columns='Rubrik', values='Percentage', fill_value=0)

# %%
renewable_pivoted_data = renewableEnergydataInlandImport.pivot_table(index='Jahr', columns='Energietraeger', values='Percentage', fill_value=0)

# %%
renewable_tj_pivoted_data = renewableEnergydataInlandImport.pivot_table(index='Jahr', columns='Energietraeger', values='TJ', fill_value=0)

# %%
# Pivot the data for plotting
energyInlandImport_pivoted_data = EnergiedatenInlandImport.pivot_table(index='Jahr', columns='Energietraeger', values='Percentage', fill_value=0)

# %%
# Merge with population data
energy_endverbrauch_mit_bevoelkerung = pd.merge(EnergieDatenEndverbrauchSummiert, BevoelkerungBIP, on='Jahr')
energy_endverbrauch_mit_bevoelkerung['Energy_pro_kopf'] = energy_endverbrauch_mit_bevoelkerung['TotalEnergy'] / energy_endverbrauch_mit_bevoelkerung['Bevölkerung']
print(energy_endverbrauch_mit_bevoelkerung)
# Out:
#      Jahr                Energietraeger      TJ  TotalEnergy  Percentage  \
# 0    1980                  Elektrizität  126910       698290   18.174397
# 1    1980                 Erdölprodukte  489480       698290   70.096951
# 2    1980                     Fernwärme    7920       698290    1.134199
# 3    1980                           Gas   30370       698290    4.349196
# 4    1980                   Holzenergie   26280       698290    3.763479
# ..    ...                           ...     ...          ...         ...
# 468  2022                         Kohle    3850       765070    0.503222
# 469  2022     Müll und Industrieabfälle   12280       765070    1.605082
# 470  2022                         Rohöl       0       765070    0.000000
# 471  2022  Uebrige erneuerbare Energien   32260       765070    4.216608
# 472  2022                   Wasserkraft       0       765070    0.000000
#
#      Bevölkerung        BIP  Bip_pro_Kopf  Energy_pro_kopf
# 0        6335243  205370.18      3.241710         0.110223
# 1        6335243  205370.18      3.241710         0.110223
# 2        6335243  205370.18      3.241710         0.110223
# 3        6335243  205370.18      3.241710         0.110223
# 4        6335243  205370.18      3.241710         0.110223
# ..           ...        ...           ...              ...
# 468      8815385  781460.27      8.864732         0.086788
# 469      8815385  781460.27      8.864732         0.086788
# 470      8815385  781460.27      8.864732         0.086788
# 471      8815385  781460.27      8.864732         0.086788
# 472      8815385  781460.27      8.864732         0.086788
#
# [473 rows x 9 columns]

# %% [markdown]
# # 3. Daten analysieren und präsentieren

# %% [markdown]
# In diesem Kapital wird die Datenanalyse der gesammelten Daten durchgeführt. Im Rahmen dieser Analyse werden die vorliegenden Daten auf Konsistenz, Relevanz und Korrektheit untersucht, um sicherzustellen, dass die Daten in der benötigen Qualität und Quantität zur Verfügung stehen, damit die Daten korrekt interpretiert und visualisiert werden können. Damit die Daten analyisiert und visualisiert werden können, werden die zusätzlich notwendigen Bibliotheken wie "matplotlib", "numpy" und "seaborn" geladen

# %%
#Bibliotheken laden

import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb
import ipywidgets as widgets
from IPython.display import display

# %% [markdown]
# ## 4.1 Energieverbrauch

# %% [markdown]
# Um die erste Fragestellung zu beantworten (Wie hat sich der gesamte Energieverbrauch der Energieträger, Sektoren und pro Kopf entwickelt?) , werden die Parameter der Energieverbrauchsdaten analysiert. So dass der Verbrauch untersucht werden kann, wurden die nachfolgenden Daten zur weiteren Verwendung vorbereitet:
#
# *   Bevölkerung
# *   Bruttoverbrauch nach Sektoren
# *   Bruttoverbrauch nach Energieträger

# %% [markdown]
# ### 4.1.1 Analyse Entwicklung Energieverbrauch nach Energieträger

# %% [markdown]
# Um die erste Fragestellung in Bezug der Energieträger zu beantworten, werden die Parameter des Bruttoverbrauchs nach Energieträger analysiert.

# %%
# Check the first few rows to understand its structure
print(Energiedaten.head())

# Display basic information about the dataset
print(Energiedaten.info())

# Frequency of each category in 'Rubrik' and 'Energietraeger'
print("Frequency of Categories in Rubrik:\n", Energiedaten['Rubrik'].value_counts())
print("Frequency of Categories in Energietraeger:\n", Energiedaten['Energietraeger'].value_counts())
# Out:
#    Jahr           Rubrik Energietraeger      TJ
# 0  1980  Bruttoverbrauch   Elektrizität  -29450
# 1  1980  Bruttoverbrauch  Erdölprodukte  321250
# 2  1980  Bruttoverbrauch      Fernwärme       0
# 3  1980  Bruttoverbrauch            Gas   36280
# 4  1980  Bruttoverbrauch    Holzenergie   26280
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8987 entries, 0 to 8986
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Jahr            8987 non-null   int64
#  1   Rubrik          8987 non-null   object
#  2   Energietraeger  8987 non-null   object
#  3   TJ              8987 non-null   int64
# dtypes: int64(2), object(2)
# memory usage: 281.0+ KB
# None
# Frequency of Categories in Rubrik:
#  Rubrik
# Bruttoverbrauch                                                                          473
# Energieumwandlung - Kernkraftwerke                                                       473
# Lagerveränderung                                                                         473
# Inlandproduktion                                                                         473
# Import                                                                                   473
# Export                                                                                   473
# Energieumwandlung - konventionell-thermische Kraft-, Fernheiz- und Fernheizkraftwerke    473
# Energieumwandlung - Wasserkraftwerke                                                     473
# Energieumwandlung - Raffinerien                                                          473
# Energieumwandlung - Gaswerke                                                             473
# Eigenverbrauch des Energiesektors, Netzverluste, Verbrauch der Speicherungen             473
# Energieumwandlung - Diverse Erneuerbare                                                  473
# Endverbrauch - Verkehr                                                                   473
# Endverbrauch - Total                                                                     473
# Endverbrauch - Statistische Differenz inkl. Landwirtschaft                               473
# Endverbrauch - Industrie                                                                 473
# Endverbrauch - Haushalte                                                                 473
# Endverbrauch - Dienstleistungen                                                          473
# Nichtenergetischer Verbrauch                                                             473
# Name: count, dtype: int64
# Frequency of Categories in Energietraeger:
#  Energietraeger
# Elektrizität                    817
# Erdölprodukte                   817
# Fernwärme                       817
# Gas                             817
# Holzenergie                     817
# Kernbrennstoffe                 817
# Kohle                           817
# Müll und Industrieabfälle       817
# Rohöl                           817
# Uebrige erneuerbare Energien    817
# Wasserkraft                     817
# Name: count, dtype: int64

# %%
print(EnergieDatenEndverbrauchSummiert['TotalEnergy'].describe())
print(EnergieDatenEndverbrauchSummiert['TJ'].describe())
# Out:
# count       473.000000
# mean     814630.930233
# std       61018.371323
# min      672750.000000
# 25%      761970.000000
# 50%      836670.000000
# 75%      856810.000000
# max      905630.000000
# Name: TotalEnergy, dtype: float64
# count       473.000000
# mean      74057.357294
# std      136631.252097
# min           0.000000
# 25%           0.000000
# 50%       11310.000000
# 75%       64160.000000
# max      523760.000000
# Name: TJ, dtype: float64

# %%
def plot_pie(year):
    # Filter data for the selected year
    filtered_data = EnergieDatenEndverbrauchSummiert[EnergieDatenEndverbrauchSummiert['Jahr'] == year]
    labels = filtered_data['Energietraeger']
    sizes = filtered_data['Percentage']

    # Colors will be assigned by a colormap
    cmap = plt.get_cmap('tab20')  # Enhanced color map
    colors = [cmap(i) for i in np.linspace(0, 1, len(labels))]

    # Exploding the largest piece a little
    explode = [0.1 for i in sizes.index]

    # Create pie chart
    plt.figure(figsize=(10, 8))
    patches, texts, autotexts = plt.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=140, colors=colors, explode=explode, pctdistance=1.1)

    # Improve the display of the labels and percentage values
    for text, autotext in zip(texts, autotexts):
        text.set_fontsize(10)
        text.set_color('white')
        autotext.set_fontsize(10)

    # Add a legend
    plt.legend(patches, labels, title="Energieträger", loc="best", bbox_to_anchor=(1, 0, 0.5, 1))
    plt.title(f'Energieverbrauch nach Energieträger {year}')
    plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
    plt.show()

plot_pie(2022)

# %%
# Variante 2: Bar Plot horizontal integrieren
def plot_horizontal_bar(year):
    # Assuming EnergieDatenEndverbrauchSummiert is loaded as a DataFrame
    # Filter data for the selected year
    filtered_data = EnergieDatenEndverbrauchSummiert[EnergieDatenEndverbrauchSummiert['Jahr'] == year]
    labels = filtered_data['Energietraeger']
    sizes = filtered_data['Percentage']  # Assuming 'Percentage' is a column in your DataFrame

    # Sort the data by sizes in descending order for better visualization
    sorted_indices = sizes.argsort()
    sizes = sizes.iloc[sorted_indices]
    labels = labels.iloc[sorted_indices]

    # Colors will be assigned by a colormap
    cmap = plt.get_cmap('tab20c')  # Enhanced color map for better visual distinction
    colors = [cmap(i) for i in np.linspace(0, 1, len(labels))]

    # Create horizontal bar plot
    plt.figure(figsize=(12, 8))
    bars = plt.barh(labels, sizes, color=colors, edgecolor='black')

    # Add value labels to each bar
    for bar in bars:
        plt.text(bar.get_width() + 1,  # Add a little offset to place text outside the bar
                 bar.get_y() + bar.get_height()/2,
                 f'{bar.get_width():.1f}%',
                 va='center', ha='left', color='black', fontsize=10, fontweight='bold')

    # Title and labels
    plt.title(f'Energieverbrauch nach Energieträger im Jahr {year}')
    plt.xlabel('Prozentanteil (%)')
    plt.ylabel('Energieträger')

    # Set x-axis to go from 0 to 100
    plt.xlim(0, 60)

    # Display the plot
    plt.gca().invert_yaxis()  # Invert y axis to have the largest at the top
    plt.show()

# Example usage, assuming your DataFrame and a specific year
plot_horizontal_bar(2022)

# %% [markdown]
# ### 4.1.2 Visualisierung Energieverbrauch nach Energieträger (DATA OK)

# %% [markdown]
# Hier werden die analysierten Daten visualisiert und präsentiert.

# %%
# Create a stacked 100% area plot
plt.figure(figsize=(12, 8))
colors = ['#ffd700', '#ffb14e', '#fa8775', '#ea5f94', '#cd34b5', '#9d02d7', '#0000ff', '#0000a2']
plt.stackplot(percentage_pivoted_data .index, percentage_pivoted_data .T, labels=percentage_pivoted_data.columns, colors=colors)
plt.title('Gestapeltes Flächendiagramm Entwicklung Energieträger 1980 bis 2022')
plt.xlabel('Jahr')
plt.ylabel('Bruttoverbrauch in %')
plt.legend(loc='upper left', bbox_to_anchor=(1, 1), title='Energieträger')
plt.show()

# %%
# Variante 2: stacked area Plot integrieren (also den Plot ohne 100%)
# Create a stacked 100% area plot
plt.figure(figsize=(12, 8))
colors = ['#ffd700', '#ffb14e', '#fa8775', '#ea5f94', '#cd34b5', '#9d02d7', '#0000ff', '#0000a2']
plt.stackplot(totalEnergy_pivoted_data.index, totalEnergy_pivoted_data.T, labels=totalEnergy_pivoted_data.columns, colors=colors)
plt.title('Gestapeltes Flächendiagramm Entwicklung Energieträger 1980 bis 2022')
plt.xlabel('Jahr')
plt.ylabel('Bruttoverbrauch in %')
plt.legend(loc='upper left', bbox_to_anchor=(1, 1), title='Energieträger')
plt.show()

# %%
# Variante 3: stacked Bar Plot integrieren
# Define custom colors for the stackplot
colors = ['#ffd700', '#ffb14e', '#fa8775', '#ea5f94', '#cd34b5', '#9d02d7', '#0000ff', '#0000a2']

# Create a stacked bar plot
plt.figure(figsize=(12, 8))
bottom = np.zeros(len(percentage_pivoted_data))
for col, color in zip(percentage_pivoted_data.columns, colors):
    plt.bar(percentage_pivoted_data.index, percentage_pivoted_data[col], bottom=bottom, color=color, label=col)
    bottom += percentage_pivoted_data[col]

plt.title('Gestapeltes Balkendiagramm der Entwicklung der Energieträger von 1980 bis 2022')
plt.xlabel('Jahr')
plt.ylabel('Bruttoverbrauch in TJ')
plt.xticks(rotation=45)  # Rotate the x-axis labels for better readability
plt.legend(loc='upper left', bbox_to_anchor=(1, 1), title='Energieträger')
plt.tight_layout()  # Adjust layout to fit everything
plt.show()

# %%
# Variante 3: stacked Bar Plot integrieren
# Define custom colors for the stackplot
colors = ['#ffd700', '#ffb14e', '#fa8775', '#ea5f94', '#cd34b5', '#9d02d7', '#0000ff', '#0000a2']

# Create a stacked bar plot
plt.figure(figsize=(12, 8))
bottom = np.zeros(len(totalEnergy_pivoted_data))
for col, color in zip(totalEnergy_pivoted_data.columns, colors):
    plt.bar(totalEnergy_pivoted_data.index, totalEnergy_pivoted_data[col], bottom=bottom, color=color, label=col)
    bottom += totalEnergy_pivoted_data[col]

plt.title('Gestapeltes Balkendiagramm der Entwicklung der Energieträger von 1980 bis 2022')
plt.xlabel('Jahr')
plt.ylabel('Bruttoverbrauch in TJ')
plt.xticks(rotation=45)  # Rotate the x-axis labels for better readability
plt.legend(loc='upper left', bbox_to_anchor=(1, 1), title='Energieträger')
plt.tight_layout()  # Adjust layout to fit everything
plt.show()

# %%
# Define custom colors for the plot
colors = ['#ffd700', '#ffb14e', '#fa8775', '#ea5f94', '#cd34b5', '#9d02d7', '#0000ff', '#0000a2']

# Create a multiline plot
plt.figure(figsize=(12, 8))
for col, color in zip(totalEnergy_pivoted_data.columns, colors):
    plt.plot(totalEnergy_pivoted_data.index, totalEnergy_pivoted_data[col], marker='o', color=color, label=col)

plt.title('Entwicklung der Energieträger von 1980 bis 2022')
plt.xlabel('Jahr')
plt.ylabel('Bruttoverbrauch in TJ')
plt.xticks(rotation=45)  # Rotate the x-axis labels for better readability
plt.grid(True)  # Add a grid for easier reading of values
plt.legend(loc='upper left', bbox_to_anchor=(1, 1), title='Energieträger')
plt.tight_layout()  # Adjust layout to fit everything
plt.show()

# %% [markdown]
# Lorem ipsum ...

# %% [markdown]
# ### 4.1.3 Analyse Entwicklung Energieverbrauch nach Sektoren

# %% [markdown]
# Auch hier soll die Analyse eine Antwort auf die erste Fragestellung geben, jedoch werden hier die Parameter der Energieverbrauchsdaten in Bezug der Sektoren analysiert.

# %%
# Assuming the DataFrame 'EnergieDatenSektorenSummiert' is loaded, inspect its structure
# Descriptive statistics by sector
grouped_data = EnergieDatenSektorenSummiert.groupby('Rubrik')
print(grouped_data['TJ'].describe())
# Out:
#                                                     count           mean  \
# Rubrik
# Endverbrauch - Dienstleistungen                      43.0  135620.697674
# Endverbrauch - Haushalte                             43.0  241715.581395
# Endverbrauch - Industrie                             43.0  155475.348837
# Endverbrauch - Statistische Differenz inkl. Lan...   43.0    9521.395349
# Endverbrauch - Verkehr                               43.0  272297.906977
#
#                                                              std       min  \
# Rubrik
# Endverbrauch - Dienstleistungen                      9279.975471  116060.0
# Endverbrauch - Haushalte                            12539.648796  211310.0
# Endverbrauch - Industrie                             9592.154867  132160.0
# Endverbrauch - Statistische Differenz inkl. Lan...   2224.394601    6220.0
# Endverbrauch - Verkehr                              39638.433103  186700.0
#
#                                                          25%       50%  \
# Rubrik
# Endverbrauch - Dienstleistungen                     129055.0  137410.0
# Endverbrauch - Haushalte                            233585.0  242310.0
# Endverbrauch - Industrie                            150530.0  156170.0
# Endverbrauch - Statistische Differenz inkl. Lan...    8365.0    9210.0
# Endverbrauch - Verkehr                              249555.0  283710.0
#
#                                                          75%       max
# Rubrik
# Endverbrauch - Dienstleistungen                     142920.0  152290.0
# Endverbrauch - Haushalte                            250250.0  266110.0
# Endverbrauch - Industrie                            162550.0  171310.0
# Endverbrauch - Statistische Differenz inkl. Lan...   10435.0   16150.0
# Endverbrauch - Verkehr                              306695.0  315520.0

# %%
def plot_pie(year):
    # Filter data for the selected year
    filtered_data = EnergieDatenSektorenSummiert[EnergieDatenSektorenSummiert['Jahr'] == year]
    labels = filtered_data['Rubrik']
    sizes = filtered_data['Percentage']

    # Colors will be assigned by a colormap
    cmap = plt.get_cmap('tab20')  # Enhanced color map
    colors = [cmap(i) for i in np.linspace(0, 1, len(labels))]

    # Exploding the largest piece a little
    explode = [0.1 for i in sizes.index]

    # Create pie chart
    plt.figure(figsize=(10, 8))
    patches, texts, autotexts = plt.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=140, colors=colors, explode=explode, pctdistance=1.1)

    # Improve the display of the labels and percentage values
    for text, autotext in zip(texts, autotexts):
        text.set_fontsize(10)
        text.set_color('white')
        autotext.set_fontsize(10)

    # Add a legend
    plt.legend(patches, labels, title="Rubrik", loc="best", bbox_to_anchor=(1, 0, 0.5, 1))
    plt.title(f'Energy Usage Breakdown for {year}')
    plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
    plt.show()

plot_pie(2022)

# %% [markdown]
# ### 4.1.4 Visualisierung Energieverbrauch nach Sektoren  (DATA OK)

# %% [markdown]
# Hier werden die analysierten Daten visualisiert und präsentiert.

# %%
# Create a stacked area plot
plt.figure(figsize=(12, 8))
colors = ['#ffb14e', '#fa8775', '#ea5f94', '#cd34b5', '#9d02d7', '#0000ff', '0000a2']
# colors = ['#012E4A', '#036280', '#378BA4', '#81BECE', '#E8EDE7']
plt.stackplot(totalSector_pivoted_data.index, totalSector_pivoted_data.T, labels=totalSector_pivoted_data.columns, colors=colors)
plt.title('Gestapeltes Flächendiagramm Entwicklung Sektoren 1980 bis 2022')
plt.xlabel('Jahr')
plt.ylabel('Bruttoverbauch in Prozent')
plt.legend(loc='upper left', bbox_to_anchor=(1, 1), title='Rubrik')
plt.show()

# %% [markdown]
# ### 4.1.5 Analyse Entwicklung Energieverbrauch pro Kopf

# %% [markdown]
# Auch hier soll wieder die Analyse eine Antwort auf die erste Fragestellung geben, jedoch werden hier die Parameter der Energieverbrauchsdaten pro Kopf der schweizer Bevölkerung analysiert werden.

# %%
# Welche Funktion(en) zur Datenanalyse ausführen?
print(energy_endverbrauch_mit_bevoelkerung['Energy_pro_kopf'].describe())
# Out:
# count    473.000000
# mean       0.110654
# std        0.008895
# min        0.086360
# 25%        0.106202
# 50%        0.114172
# 75%        0.116962
# max        0.122092
# Name: Energy_pro_kopf, dtype: float64

# %% [markdown]
# ### 4.1.6 Visualisierung Energieverbrauch pro Kopf (DATA OK)

# %% [markdown]
# Hier werden die analysierten Daten visualisiert und präsentiert.

# %%
# Linear Regression to fit trend line
x = energy_endverbrauch_mit_bevoelkerung['Jahr'].astype(float)  # Convert years to float for regression analysis
y = energy_endverbrauch_mit_bevoelkerung['Energy_pro_kopf']
slope, intercept = np.polyfit(x, y, 1)  # Perform linear regression
trend_line = slope * x + intercept

# Bar chart and trend line
plt.figure(figsize=(12, 6))
plt.bar(energy_endverbrauch_mit_bevoelkerung['Jahr'], energy_endverbrauch_mit_bevoelkerung['Energy_pro_kopf'], color='blue', label='Energieverbrauch pro Kopf')
plt.plot(energy_endverbrauch_mit_bevoelkerung['Jahr'], trend_line, color='red', linewidth=2, label='Trendlinie')  # Plot trend line
plt.title('Energieverbrauch pro Kopf 1980 bis 2022')
plt.xlabel('Jahr')
plt.ylabel('Energieverbrauch pro Kopf')
plt.xticks(rotation=45)
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 4.2 Stromproduktion

# %% [markdown]
# Um die zweite Fragestellung zu beantworten (Wie hat sich die Stromproduktion in der Schweiz in Bezug der erneuerbaren und nicht erneuerbaren Energien entwickelt) , werden die Parameter der Energieproduktion analysiert. So dass die Produktion untersucht werden kann, stehen die nachfolgenden Daten zur Verfügung:
#
# *   Inlandproduktion
# *   Import

# %%
# Create a stacked area plot
plt.figure(figsize=(12, 8))
colors = ['#ffd700', '#ffb14e', '#fa8775', '#ea5f94', '#cd34b5', '#9d02d7', '#0000ff', '#0000a2', '#000000']
plt.stackplot(energyInlandImport_pivoted_data.index, energyInlandImport_pivoted_data.T, labels=energyInlandImport_pivoted_data.columns, colors=colors)
plt.title('Gestapeltes Flächendiagramm Energieproduktion Energieträger')
plt.xlabel('Year')
plt.ylabel('Gesamtproduktion in Prozent')
plt.legend(loc='upper left', bbox_to_anchor=(1, 1), title='Energieträger')
plt.show()

# %% [markdown]
# ### 4.2.1 Analyse Entwickung Stromproduktion erneuerbare Energien

# %% [markdown]
# Um die Fragestellung in Bezug der Stromproduktionsentwickung zu beantworten, werden die Parameter der Stromproduktion mit erneuerbaren Energien analysiert.

# %%
#Code von Michi

# Welche Funktion(en) zur Datenanalyse ausführen?

#describe?
#head?
#info?
#...
#...
#Vorschlag: erste 5 und letzte 5 Zeilen des Dataframes

#Periode -> 1980 - 2022
#Daten -> StromProduktionErneuerbareEnergien = Import ['Uebrige erneuerbare Energien' + 'Holzenergie' + 'Wasserkraft']  + Inlandproduktion ['Uebrige erneuerbare Energien' + 'Holzenergie' + 'Wasserkraft']
#Status -> Ready to update existing code (code refers only to Inlandproduktion, expand with Import)

# %%
# Create a stacked bar plot
fig, ax = plt.subplots(figsize=(12, 8))
bottom = np.zeros(len(renewable_pivoted_data))  # This will keep track of the cumulative bottom position

for col in renewable_pivoted_data.columns:
    ax.bar(renewable_pivoted_data.index, renewable_pivoted_data[col], bottom=bottom, label=col)
    bottom += renewable_pivoted_data[col].values  # Update the bottom position for the next stack

ax.set_title('Stacked Bar Plot of Energy Production by Type Over Years')
ax.set_xlabel('Year')
ax.set_ylabel('Percentage of Total Production')
ax.legend(title='Energy Types', loc='upper left', bbox_to_anchor=(1, 1))

plt.show()

# %% [markdown]
# ### 4.2.2 Visualisierung Entwicklung Stormproduktion erneuerbare Energien

# %% [markdown]
# Hier werden die analysierten Daten visualisiert und präsentiert.

# %%
#Code von Michi
#Periode -> 1980 - 2022
#Hier Visualisierung mit "Single Line Chart" machen
#Daten -> StromProduktionErneuerbareEnergien = Import ['Uebrige erneuerbare Energien' + 'Holzenergie']  + Inlandproduktion ['Uebrige erneuerbare Energien' + 'Holzenergie' + 'Wasserkraft']
#Status -> Ready to update existing code

# %%
fig, ax = plt.subplots(figsize=(12, 8))

# Plotting each column as a separate line
for col in renewable_tj_pivoted_data.columns:
    ax.plot(renewable_tj_pivoted_data.index, renewable_tj_pivoted_data[col], marker='o', label=col)

# Setting up the chart with titles and labels
ax.set_title('Energy Production by Type Over Years')
ax.set_xlabel('Year')
ax.set_ylabel('Energy Production (Units/TJ/GWh etc.)')  # Adjust the unit based on your data
ax.legend(title='Energy Types', loc='upper left', bbox_to_anchor=(1, 1))

# Show the plot
plt.show()

# %% [markdown]
# ### 4.2.3 Analyse Entwickung Stromproduktion nicht erneuerbare Energien (in Bearbeitung)

# %% [markdown]
# Um die Fragestellung in Bezug der Stromproduktionsentwickung zu beantworten, werden die Parameter der Stromproduktion mit nicht erneuerbaren Energien analysiert.

# %%
#Code von Michi

# Welche Funktion(en) zur Datenanalyse ausführen?

#describe?
#head?
#info?
#...
#...
#Vorschlag: erste 5 und letzte 5 Zeilen des Dataframes

#Periode -> 1980 - 2022
#Hier nur Daten für Analyse ausgeben
#Daten -> StromProduktionNichtErneuerbareEnergien = Inlandproduktion ['Gas' + 'Müll und Industrieabfälle'] + Import ['Elektrizität' + 'Erdölprodukte' + 'Fernwärme' + 'Gas' + 'Holzenergie' + 'Kernbrennstoffe' + 'Kohle' + 'Müll und Industrieabfälle' + 'Rohöl']
#Status -> Ready for coding

# %% [markdown]
# ### 4.2.4 Visualisierung Entwicklung Stormproduktion nicht erneuerbare Energien (in Bearbeitung)

# %% [markdown]
# Hier werden die analysierten Daten visualisiert und präsentiert.

# %%
#Code von Michi
#Periode -> 1980 - 2022
#Hier Visualisierung mit "Single Line Chart" machen
#Daten -> StromProduktionNichtErneuerbareEnergien = Inlandproduktion ['Gas' + 'Müll und Industrieabfälle'] + Import ['Elektrizität' + 'Erdölprodukte' + 'Fernwärme' + 'Gas' + 'Holzenergie' + 'Kernbrennstoffe' + 'Kohle' + 'Müll und Industrieabfälle' + 'Rohöl']
#Status -> Ready for coding

# %% [markdown]
# ### 4.2.5 Analyse Entwickung Stromproduktion Kernenergie

# %% [markdown]
# Um die Fragestellung in Bezug der Stromproduktionsentwickung zu beantworten, werden die Parameter der Stromproduktion mit Kernenergie analysiert

# %%
#Code von Michi

# Welche Funktion(en) zur Datenanalyse ausführen?

#describe?
#head?
#info?
#...
#...
#Vorschlag: erste 5 und letzte 5 Zeilen des Dataframes

#Periode -> 1980 - 2022
#Hier nur Daten für Analyse ausgeben
#Daten -> StromProduktionKernenergie = Import ['Kernbrennstoffe'] + Inlandproduktion ['Kernbrennstoffe']
#Status -> Ready for coding

# %% [markdown]
# ### 4.2.6 Visualisierung Entwicklung Stormproduktion Kernenergie

# %% [markdown]
# Hier werden die analysierten Daten visualisiert und präsentiert.

# %%
#Code von Michi
#Periode -> 1980 - 2022
#Hier Visualisierung mit "Single Line Chart" machen
#Daten -> StromProduktionKernenergie = Import ['Kernbrennstoffe'] + Inlandproduktion ['Kernbrennstoffe']
#Status -> Ready for coding

# %% [markdown]
# ### 4.2.7 Analyse Entwicklung gesamte Stormproduktion

# %%
# Kommentar Andi

# Welche Funktion(en) zur Datenanalyse ausführen?

#describe?
#head?
#info?
#...
#...
#Vorschlag: erste 5 und letzte 5 Zeilen des Dataframes

# Hier noch zu Daten Inlandproduktion die Daten vom Energieimport integrieren
# EnergieImportTotal = Import ['Elektrizität' + 'Erdölprodukte' + 'Fernwärme' + 'Gas' + 'Holzenergie' + 'Kernbrennstoffe' + 'Kohle' + 'Müll und Industrieabfälle' + 'Rohöl' + 'Uebrige erneuerbare Energien' + 'Wasserkraft']
# EnergieproduktionTotal = EnergieImportTotal + EnergieInlandproduktionTotal

# Load data
df = pd.read_csv('https://raw.githubusercontent.com/michaelzimmermannstudhslu/BINA_2024_energy_research/main/data/energiebilanz_ch.csv')

# Clean data
df.dropna(inplace=True)
df['TJ'] = pd.to_numeric(df['TJ'], errors='coerce')
df['TJ'] = df['TJ'].abs()
df.dropna(subset=['TJ'], inplace=True)
df['TJ'] = df['TJ'].astype(int)

# Apply correct filtering for "Inlandproduktion"
df = df[df['Rubrik'] == 'Inlandproduktion']

print(df['Energietraeger'].unique())

# Group by year and Energieträger, sum up TJ
energy_sum_by_year_and_type = df.groupby(['Jahr', 'Energietraeger'])['TJ'].sum().reset_index()

# Group by year only, sum up TJ for total energy
total_energy_by_year = df.groupby('Jahr')['TJ'].sum().reset_index()
total_energy_by_year.rename(columns={'TJ': 'TotalEnergy'}, inplace=True)

# Merge while calculating the percentage
merged_df = pd.merge(energy_sum_by_year_and_type, total_energy_by_year, on='Jahr')
merged_df['Percentage'] = (merged_df['TJ'] / merged_df['TotalEnergy']) * 100

# Pivot the data for plotting by Energieträger
pivoted_data = merged_df.pivot_table(index='Jahr', columns='Energietraeger', values='Percentage', fill_value=0)

# Create a stacked area plot
plt.figure(figsize=(12, 8))
colors = ['#ffd700', '#ffb14e', 'peru', '#ea5f94', 'red', 'black', 'limegreen', '#0000a2', '#000000']
plt.stackplot(pivoted_data.index, pivoted_data.T, labels=pivoted_data.columns, colors=colors)
plt.title('Stacked Area Plot of Energy Production by Type Over Years')
plt.xlabel('Year')
plt.ylabel('Percentage of Total Production')
plt.legend(loc='upper left', bbox_to_anchor=(1, 1), title='Energy Types')
plt.show()
# Out:
# ['Gas' 'Holzenergie' 'Kohle' 'Müll und Industrieabfälle' 'Rohöl'
#  'Wasserkraft' 'Uebrige erneuerbare Energien' 'Erdölprodukte']

# %% [markdown]
# ### 4.2.8 Visualisierung Entwicklung gesamte Stormproduktion

# %% [markdown]
# Hier werden die analysierten Daten visualisiert und präsentiert.

# %%
# Kommentar Andi
# Hier noch zu Daten Inlandproduktion die Daten vom Energieimport integrieren
# EnergieImportTotal = Import ['Elektrizität' + 'Erdölprodukte' + 'Fernwärme' + 'Gas' + 'Holzenergie' + 'Kernbrennstoffe' + 'Kohle' + 'Müll und Industrieabfälle' + 'Rohöl' + 'Uebrige erneuerbare Energien' + 'Wasserkraft']
# EnergieproduktionTotal = EnergieImportTotal + EnergieInlandproduktionTotal


# Load data
df = pd.read_csv('https://raw.githubusercontent.com/michaelzimmermannstudhslu/BINA_2024_energy_research/main/data/energiebilanz_ch.csv')

# Clean data
df.dropna(inplace=True)
df['TJ'] = pd.to_numeric(df['TJ'], errors='coerce')
df['TJ'] = df['TJ'].abs()
df.dropna(subset=['TJ'], inplace=True)
df['TJ'] = df['TJ'].astype(int)

# Apply correct filtering for "Inlandproduktion"
df = df[df['Rubrik'] == 'Inlandproduktion']

# Define renewable and non-renewable energy sources
renewables = ['Wasserkraft', 'Uebrige erneuerbare Energien']
non_renewables = ['Gas', 'Holzenergie', 'Kohle', 'Müll und Industrieabfälle', 'Rohöl', 'Erdölprodukte']

# Group by year and Energieträger, sum up TJ
energy_sum_by_year_and_type = df.groupby(['Jahr', 'Energietraeger'])['TJ'].sum().reset_index()

# Separate renewable and non-renewable energy data
energy_sum_by_year_and_type['Type'] = energy_sum_by_year_and_type['Energietraeger'].apply(lambda x: 'Renewable' if x in renewables else 'Non-Renewable')

# Group by year and type
total_energy_by_type = energy_sum_by_year_and_type.groupby(['Jahr', 'Type'])['TJ'].sum().unstack(fill_value=0)

# Plot stacked area plot
plt.figure(figsize=(10, 7))
plt.stackplot(total_energy_by_type.index, total_energy_by_type['Renewable'], total_energy_by_type['Non-Renewable'], labels=['Renewable', 'Non-Renewable'], colors=['#8fbc8f', '#ff6347'])
plt.title('Energy Production by Type Over Years')
plt.xlabel('Year')
plt.ylabel('Total TJ')
plt.legend(loc='upper left')
plt.show()

# %%
# Kommentar Andi
# Hier noch zu Daten Inlandproduktion die Daten vom Energieimport integrieren
# EnergieImportTotal = Import ['Elektrizität' + 'Erdölprodukte' + 'Fernwärme' + 'Gas' + 'Holzenergie' + 'Kernbrennstoffe' + 'Kohle' + 'Müll und Industrieabfälle' + 'Rohöl' + 'Uebrige erneuerbare Energien' + 'Wasserkraft']
# EnergieproduktionTotal = EnergieImportTotal + EnergieInlandproduktionTotal


# Load data
df = pd.read_csv('https://raw.githubusercontent.com/michaelzimmermannstudhslu/BINA_2024_energy_research/main/data/energiebilanz_ch.csv')

# Clean data
df.dropna(inplace=True)
df['TJ'] = pd.to_numeric(df['TJ'], errors='coerce')
df['TJ'] = df['TJ'].abs()
df.dropna(subset=['TJ'], inplace=True)
df['TJ'] = df['TJ'].astype(int)

# Apply correct filtering for "Inlandproduktion"
df = df[df['Rubrik'] == 'Inlandproduktion']

# Define renewable and non-renewable energy sources
renewables = ['Wasserkraft', 'Uebrige erneuerbare Energien']
non_renewables = ['Gas', 'Holzenergie', 'Kohle', 'Müll und Industrieabfälle', 'Rohöl', 'Erdölprodukte']

# Group by year and Energieträger, sum up TJ
energy_sum_by_year_and_type = df.groupby(['Jahr', 'Energietraeger'])['TJ'].sum().reset_index()

# Separate renewable and non-renewable energy data
energy_sum_by_year_and_type['Type'] = energy_sum_by_year_and_type['Energietraeger'].apply(lambda x: 'Renewable' if x in renewables else 'Non-Renewable')

# Group by year and type
total_energy_by_type = energy_sum_by_year_and_type.groupby(['Jahr', 'Type'])['TJ'].sum().unstack(fill_value=0)

# Fit polynomial trend lines
years = total_energy_by_type.index.values
renewable_trend = np.polyfit(years, total_energy_by_type['Renewable'], deg=3)
non_renewable_trend = np.polyfit(years, total_energy_by_type['Non-Renewable'], deg=3)

# Generate trend data
renewable_trend_line = np.poly1d(renewable_trend)(years)
non_renewable_trend_line = np.poly1d(non_renewable_trend)(years)

# Plot stacked area plot with trend lines
plt.figure(figsize=(10, 7))
plt.stackplot(years, total_energy_by_type['Renewable'], total_energy_by_type['Non-Renewable'], labels=['Renewable', 'Non-Renewable'], colors=['#8fbc8f', '#ff6347'])
plt.plot(years, renewable_trend_line, 'b--', label='Renewable Trend')
plt.plot(years, non_renewable_trend_line, 'r--', label='Non-Renewable Trend')
plt.title('Energy Production by Type Over Years')
plt.xlabel('Year')
plt.ylabel('Total TJ')
plt.legend(loc='upper left')
plt.show()

# %%
# Dieses Diagramm für Stromproduktion machen
# Dabei zwischen erneuerbare und nicht erneuerbare Stromproduktion unterscheiden

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# Create DataFrame
df = pd.read_csv('https://raw.githubusercontent.com/michaelzimmermannstudhslu/BINA_2024_energy_research/main/data/bip_total.csv')
df = df.dropna()

# Normalizing the size of the GDP for better visualization
size = (df['BIP'] - df['BIP'].min()) / (df['BIP'].max() - df['BIP'].min()) * 1000  # Scale GDP to use as size

plt.figure(figsize=(12, 8))
scatter = plt.scatter(df['Jahr'], df['Bevölkerung'], s=size, alpha=0.5, color='blue', edgecolors='black')
plt.title('Population and GDP of Switzerland (1980 - 2022)')
plt.xlabel('Year')
plt.ylabel('Population')
plt.grid(True)

# Adding a color bar for sizes, which represent GDP values
# Create a fake scale for the color bar
sizes = [min(df['BIP']), max(df['BIP'])]
sizes_labels = ['Low GDP', 'High GDP']
plt.scatter([], [], c='blue', alpha=0.5, s=(min(size)), label=sizes_labels[0], edgecolors='black')
plt.scatter([], [], c='blue', alpha=0.5, s=(max(size)), label=sizes_labels[1], edgecolors='black')
plt.legend(scatterpoints=1, frameon=False, labelspacing=1, title='GDP Scale', bbox_to_anchor=(1.05, 1))

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import numpy as np

# Load data
df = pd.read_csv('https://raw.githubusercontent.com/michaelzimmermannstudhslu/BINA_2024_energy_research/main/data/energiebilanz_ch.csv')

# Clean data
df.dropna(inplace=True)
df['TJ'] = pd.to_numeric(df['TJ'], errors='coerce')
df['TJ'] = df['TJ'].abs()
df.dropna(subset=['TJ'], inplace=True)
df['TJ'] = df['TJ'].astype(int)

# Apply correct filtering
df = df[(df['Rubrik'] == 'Inlandproduktion') | (df['Rubrik'] == 'Import')]

# Group by year and Energieträger, sum up TJ
energy_sum_by_year_and_type = df.groupby(['Jahr', 'Energietraeger'])['TJ'].sum().reset_index()

# Group by year only, sum up TJ for total energy
total_energy_by_year = df.groupby('Jahr')['TJ'].sum().reset_index()
total_energy_by_year.rename(columns={'TJ': 'TotalEnergy'}, inplace=True)

# Merge while calculating the percentage
merged_df = pd.merge(energy_sum_by_year_and_type, total_energy_by_year, on='Jahr')
merged_df['Percentage'] = (merged_df['TJ'] / merged_df['TotalEnergy']) * 100

# Pivot the data for plotting by Energietraeger
pivoted_data = merged_df.pivot_table(index='Jahr', columns='Energietraeger', values='Percentage', fill_value=0)

# Calculate average contribution of each Energieträger and sort columns by this average
average_contributions = pivoted_data.mean().sort_values()
pivoted_data = pivoted_data[average_contributions.index]

# Create a 3D plot
fig = plt.figure(figsize=(14, 10))
ax = fig.add_subplot(111, projection='3d')

# Define bar width and positions
width = 0.3
x_pos = np.arange(len(pivoted_data.index))

colors = plt.cm.tab20(np.linspace(0, 1, len(pivoted_data.columns)))  # Use a colormap for distinct colors

for i, col in enumerate(pivoted_data.columns):
    ax.bar(x_pos, pivoted_data[col], zs=i, zdir='y', width=width, align='center', color=colors[i], label=col)

ax.set_xlabel('Year')
ax.set_ylabel('Energy Type')
ax.set_zlabel('Percentage of Total Production')

# Customizing the y-axis to show the energy types as categories
ax.set_yticks(np.arange(len(pivoted_data.columns)))
ax.set_yticklabels(pivoted_data.columns)

plt.title('3D Stacked Bar Plot of Energy Production by Type Over Years')
ax.view_init(elev=20, azim=-60)  # Adjust the viewing angle for better visibility

ax.legend(loc='upper left', bbox_to_anchor=(1.1, 1))
plt.show()

# %% [markdown]
# ## 4.3 Energieeffizienz (nicht bereit für Coding)

# %% [markdown]
# Um die dritte Fragestellung zu beantworten (Wie hat sich die Energieeffizienz entwickelt?) , werden die ausgewählten Parameter miteinander verglichen und analysiert. So dass die Entwicklung der Energieeffizenz untersucht werden kann, stehen die nachfolgenden Daten zur Verfügung:
#
# *   Bevölkerung
# *   Bruttoinlandprodukt
# *   CO2 Ausstoss
# *   Energiebruttoverbrauch

# %% [markdown]
# ### 4.3.1 Analyse Entwickung Energieeffizienz (CO2 Ausstoss und Bruttoverbrauch)

# %% [markdown]
# Um die Fragestellung in Bezug der Energieeffizienz zu beantworten, werden die Parameter des C02 Ausstosses mit dem Bruttoverbrauch analysiert. Dabei wird untersucht wie sich der C02 Ausstoss im Verhältnis zum gesamten Bruttoenergieverbrauch entwickelt hat.

# %%
# Welche Funktion(en) zur Datenanalyse ausführen?

#describe?
#head?
#info?
#...
#...
#Vorschlag: erste 5 und letzte 5 Zeilen des Dataframes

# %%
# Load the data
df = pd.read_csv('https://raw.githubusercontent.com/michaelzimmermannstudhslu/BINA_2024_energy_research/main/data/co2.csv')

# Plotting
plt.figure(figsize=(10, 6))
plt.plot(df['Jahr'], df['THG'], marker='o', linestyle='-', color='blue', label='Actual THG Data')  # Actual data points

# Calculate a linear regression trendline
z = np.polyfit(df['Jahr'], df['THG'], 1)
p = np.poly1d(z)
plt.plot(df['Jahr'], p(df['Jahr']), "r--", label='Trendline')  # Add trendline

# Customize the plot
plt.title('Total Greenhouse Gas Emissions Over Time with Trendline')
plt.xlabel('Year')
plt.ylabel('Total Greenhouse Gas Emissions (THG)')
plt.grid(True)  # Ensure y-axis starts at 0
plt.legend()  # Show legend to identify the plot elements
plt.show()

# %% [markdown]
# ### 4.3.2 Visualisierung Entwickung Energieeffizienz (CO2 Ausstoss und Bruttoverbrauch)

# %% [markdown]
# Hier werden die analysierten Daten visualisiert und präsentiert.

# %%
# Load the data
df = pd.read_csv('https://raw.githubusercontent.com/michaelzimmermannstudhslu/BINA_2024_energy_research/main/data/co2.csv')

# Plotting
plt.figure(figsize=(10, 6))
plt.plot(df['Jahr'], df['THG'], marker='o', linestyle='-', color='blue', label='Actual THG Data')  # Actual data points

# Calculate a linear regression trendline
z = np.polyfit(df['Jahr'], df['THG'], 1)
p = np.poly1d(z)
plt.plot(df['Jahr'], p(df['Jahr']), "r--", label='Trendline')  # Add trendline

# Customize the plot
plt.title('Total Greenhouse Gas Emissions Over Time with Trendline')
plt.xlabel('Year')
plt.ylabel('Total Greenhouse Gas Emissions (THG)')
plt.grid(True)
plt.ylim(bottom=0, top=100)  # Ensure y-axis starts at 0
plt.legend()  # Show legend to identify the plot elements
plt.show()

# %% [markdown]
# ### 4.3.3 Analyse Entwickung Energieeffizienz (BIP und Bruttoverbrauch)

# %% [markdown]
# Um die Fragestellung in Bezug der Energieeffizienz zu beantworten, werden die Parameter des Bruttoinlandprodukts mit dem Bruttoverbrauch analysiert. Dabei wird untersucht wie sich das Bruttoinlandprodukt im Verhältnis zum gesamten Bruttoenergieverbrauch entwickelt hat.

# %%
# Welche Funktion(en) zur Datenanalyse ausführen?

#describe?
#head?
#info?
#...
#...
#Vorschlag: erste 5 und letzte 5 Zeilen des Dataframes

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load data
person_df = pd.read_csv('https://raw.githubusercontent.com/michaelzimmermannstudhslu/BINA_2024_energy_research/main/data/bip_total.csv')
energy_df = pd.read_csv('https://raw.githubusercontent.com/michaelzimmermannstudhslu/BINA_2024_energy_research/main/data/energiebilanz_ch.csv')

# Clean and process energy data
energy_df.dropna(inplace=True)
energy_df['TJ'] = pd.to_numeric(energy_df['TJ'], errors='coerce')
energy_df['TJ'] = energy_df['TJ'].abs()
energy_df.dropna(subset=['TJ'], inplace=True)
energy_df['TJ'] = energy_df['TJ'].astype(int)
energy_df = energy_df[energy_df['Rubrik'] == 'Endverbrauch - Total']

# Summarize energy data by year
total_energy_by_year = energy_df.groupby('Jahr')['TJ'].sum().reset_index()
total_energy_by_year.rename(columns={'TJ': 'TotalEnergy'}, inplace=True)

# Merge energy data with population data
merged_df = pd.merge(total_energy_by_year, person_df, on='Jahr')
merged_df['Energy_per_head'] = merged_df['TotalEnergy'] / merged_df['Bevölkerung']
merged_df['BIP_per_head'] = merged_df['BIP'] / merged_df['Bevölkerung']

# Create the plot
fig, ax1 = plt.subplots(figsize=(14, 7))

# Plot Energy per Head
color = 'tab:green'
ax1.plot(merged_df['Jahr'], merged_df['Energy_per_head'], color=color, label='Energy per Head')
ax1.set_xlabel('Jahr')
ax1.set_ylabel('Energy per Head', color=color)
ax1.tick_params(axis='y', labelcolor=color)

# Create a second y-axis for BIP per Head
ax2 = ax1.twinx()
color = 'tab:blue'
ax2.plot(merged_df['Jahr'], merged_df['BIP_per_head'], color=color, label='BIP per Head')
ax2.set_ylabel('BIP per Head', color=color)
ax2.tick_params(axis='y', labelcolor=color)

# Title and legend
plt.title('BIP pro Kopf der Schweiz mit Energy pro Kopf (1980 - 2022)')
lines1, labels1 = ax1.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
plt.legend(lines1 + lines2, labels1 + labels2, loc='upper left')

fig.tight_layout()  # Adjust layout
plt.show()  # Display the plot

# %% [markdown]
# ### 4.3.4 Visualisierung Entwickung Energieeffizienz (BIP und Bruttoverbrauch)

# %% [markdown]
# Hier werden die analysierten Daten visualisiert und präsentiert.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load data
person_df = pd.read_csv('https://raw.githubusercontent.com/michaelzimmermannstudhslu/BINA_2024_energy_research/main/data/bip_total.csv')
energy_df = pd.read_csv('https://raw.githubusercontent.com/michaelzimmermannstudhslu/BINA_2024_energy_research/main/data/energiebilanz_ch.csv')

# Clean and process energy data
energy_df.dropna(inplace=True)
energy_df['TJ'] = pd.to_numeric(energy_df['TJ'], errors='coerce')
energy_df['TJ'] = energy_df['TJ'].abs()
energy_df.dropna(subset=['TJ'], inplace=True)
energy_df['TJ'] = energy_df['TJ'].astype(int)
energy_df = energy_df[energy_df['Rubrik'] == 'Endverbrauch - Total']

# Summarize energy data by year
total_energy_by_year = energy_df.groupby('Jahr')['TJ'].sum().reset_index()
total_energy_by_year.rename(columns={'TJ': 'TotalEnergy'}, inplace=True)

# Merge energy data with population data
final_merged_df = pd.merge(total_energy_by_year, person_df, on='Jahr')
final_merged_df['Energy_per_head'] = final_merged_df['TotalEnergy'] / final_merged_df['Bevölkerung']

# Create the plot
fig, ax1 = plt.subplots(figsize=(14, 7))

# Plot Population on the primary y-axis
color = 'tab:red'
ax1.plot(final_merged_df['Jahr'], final_merged_df['Bevölkerung'], color=color, label='Bevölkerung')
ax1.set_xlabel('Jahr')
ax1.set_ylabel('Bevölkerung', color=color)
ax1.tick_params(axis='y', labelcolor=color)

# Create a second y-axis for BIP
ax2 = ax1.twinx()
color = 'tab:blue'
ax2.plot(final_merged_df['Jahr'], final_merged_df['BIP'], color=color, label='Gesammt BIP')
ax2.set_ylabel('BIP', color=color)
ax2.tick_params(axis='y', labelcolor=color)

# Create a third y-axis for Energy per Head
ax3 = ax1.twinx()
color = 'tab:green'
ax3.spines['right'].set_position(('outward', 60))  # Offset the third axis to avoid overlapping with the second axis
ax3.plot(final_merged_df['Jahr'], final_merged_df['TotalEnergy'], color=color, label='TotalEnergy')
ax3.set_ylabel('TotalEnergy', color=color)
ax3.tick_params(axis='y', labelcolor=color)

# Title and legend
plt.title('Bevölkerung und BIP der Schweiz mit der Totalen Energy (1980 - 2022)')
lines, labels = ax1.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
lines3, labels3 = ax3.get_legend_handles_labels()
plt.legend(lines + lines2 + lines3, labels + labels2 + labels3, loc='upper left')

fig.tight_layout()  # Adjust layout
plt.show()  # Display the plot

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load data
person_df = pd.read_csv('https://raw.githubusercontent.com/michaelzimmermannstudhslu/BINA_2024_energy_research/main/data/bip_total.csv')
energy_df = pd.read_csv('https://raw.githubusercontent.com/michaelzimmermannstudhslu/BINA_2024_energy_research/main/data/energiebilanz_ch.csv')

# Clean and process energy data
energy_df.dropna(inplace=True)
energy_df['TJ'] = pd.to_numeric(energy_df['TJ'], errors='coerce')
energy_df['TJ'] = energy_df['TJ'].abs()
energy_df.dropna(subset=['TJ'], inplace=True)
energy_df['TJ'] = energy_df['TJ'].astype(int)
energy_df = energy_df[energy_df['Rubrik'] == 'Endverbrauch - Total']

# Summarize energy data by year
total_energy_by_year = energy_df.groupby('Jahr')['TJ'].sum().reset_index()
total_energy_by_year.rename(columns={'TJ': 'TotalEnergy'}, inplace=True)

person_df['BIP_per_head'] = final_merged_df['BIP'] / final_merged_df['Bevölkerung']

# Merge energy data with population data
final_merged_df = pd.merge(total_energy_by_year, person_df, on='Jahr')
final_merged_df['Energy_per_head'] = final_merged_df['TotalEnergy'] / final_merged_df['Bevölkerung']

# Create the plot
fig, ax1 = plt.subplots(figsize=(14, 7))

# Plot Population on the primary y-axis
color = 'tab:red'
ax1.plot(final_merged_df['Jahr'], final_merged_df['Bevölkerung'], color=color, label='Bevölkerung')
ax1.set_xlabel('Jahr')
ax1.set_ylabel('Bevölkerung', color=color)
ax1.tick_params(axis='y', labelcolor=color)

# Create a second y-axis for BIP
ax2 = ax1.twinx()
color = 'tab:blue'
ax2.plot(final_merged_df['Jahr'], final_merged_df['BIP_per_head'], color=color, label='BIP_per_head')
ax2.set_ylabel('BIP_per_head', color=color)
ax2.tick_params(axis='y', labelcolor=color)

# Create a third y-axis for Energy per Head
ax3 = ax1.twinx()
color = 'tab:green'
ax3.spines['right'].set_position(('outward', 60))  # Offset the third axis to avoid overlapping with the second axis
ax3.plot(final_merged_df['Jahr'], final_merged_df['Energy_per_head'], color=color, label='Energy per Head')
ax3.set_ylabel('Energy per Head', color=color)
ax3.tick_params(axis='y', labelcolor=color)

# Title and legend
plt.title('Bevölkerung und BIP pro Kopf der Schweiz mit Energy pro Kopf (1980 - 2022)')
lines, labels = ax1.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
lines3, labels3 = ax3.get_legend_handles_labels()
plt.legend(lines + lines2 + lines3, labels + labels2 + labels3, loc='upper left')

fig.tight_layout()  # Adjust layout
plt.show()  # Display the plot

# %% [markdown]
# ### 4.3.5 Analyse Entwickung Energieeffizienz (Bevölkerung und Bruttoverbrauch)

# %% [markdown]
# Um die Fragestellung in Bezug der Energieeffizienz zu beantworten, werden die Parameter der Bevölkerung mit dem Bruttoverbrauch analysiert. Dabei wird untersucht wie sich die Bevölkerung im Verhältnis zum gesamten Bruttoenergieverbrauch entwickelt hat.

# %%
# Welche Funktion(en) zur Datenanalyse ausführen?

#describe?
#head?
#info?
#...
#...
#Vorschlag: erste 5 und letzte 5 Zeilen des Dataframes

# %% [markdown]
# ### 4.3.6 Visualisierung Entwickung Energieeffizienz (Bevölkerung und Bruttoverbrauch)

# %% [markdown]
# Hier werden die analysierten Daten visualisiert und präsentiert.

# %%
# Load data
person_df = pd.read_csv('https://raw.githubusercontent.com/michaelzimmermannstudhslu/BINA_2024_energy_research/main/data/bip_total.csv')
df = pd.read_csv('https://raw.githubusercontent.com/michaelzimmermannstudhslu/BINA_2024_energy_research/main/data/energiebilanz_ch.csv')
df.dropna(inplace=True)
df['TJ'] = pd.to_numeric(df['TJ'], errors='coerce')
df['TJ'] = df['TJ'].abs()
df.dropna(subset=['TJ'], inplace=True)
df['TJ'] = df['TJ'].astype(int)
df = df[df['Rubrik'] == 'Endverbrauch - Total']

# Process data
energy_sum_by_year_and_type = df.groupby(['Jahr', 'Energietraeger'])['TJ'].sum().reset_index()
total_energy_by_year = df.groupby('Jahr')['TJ'].sum().reset_index()
total_energy_by_year.rename(columns={'TJ': 'TotalEnergy'}, inplace=True)
merged_df = pd.merge(energy_sum_by_year_and_type, total_energy_by_year, on='Jahr')
merged_df['Percentage'] = (merged_df['TJ'] / merged_df['TotalEnergy']) * 100

# Merge with population data
final_merged_df = pd.merge(merged_df, person_df, on='Jahr')
final_merged_df['Energy_per_head'] = final_merged_df['TotalEnergy'] / final_merged_df['Bevölkerung']  # Correct calculation

# Assuming final_merged_df is already correctly merged and contains 'Jahr', 'Bevölkerung', and 'TotalEnergy'
# Convert 'Bevölkerung' to numeric if not already
final_merged_df['Bevölkerung'] = pd.to_numeric(final_merged_df['Bevölkerung'], errors='coerce')

# Create a figure and axis for plotting
fig, ax1 = plt.subplots(figsize=(12, 8))

# Plotting TotalEnergy on y-axis
color = 'tab:red'
ax1.set_xlabel('Year')
ax1.set_ylabel('Total Energy (TJ)', color=color)
ax1.plot(final_merged_df['Jahr'], final_merged_df['TotalEnergy'], color=color, label='Total Energy (TJ)')
ax1.tick_params(axis='y', labelcolor=color)

# Create a second y-axis for the population data
ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis
color = 'tab:blue'
ax2.set_ylabel('Population', color=color)  # we already handled the x-label with ax1
ax2.plot(final_merged_df['Jahr'], final_merged_df['Bevölkerung'], color=color, label='Population')
ax2.tick_params(axis='y', labelcolor=color)

# Title and legend
plt.title('Population and Total Energy Usage Over Years')
fig.tight_layout()  # to ensure that labels don't get cut off
# Adding legends
lines, labels = ax1.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
ax1.legend(lines + lines2, labels + labels2, loc='upper left')

# Show plot
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Load data
person_df = pd.read_csv('https://raw.githubusercontent.com/michaelzimmermannstudhslu/BINA_2024_energy_research/main/data/bip_total.csv')
df = pd.read_csv('https://raw.githubusercontent.com/michaelzimmermannstudhslu/BINA_2024_energy_research/main/data/energiebilanz_ch.csv')
df.dropna(inplace=True)
df['TJ'] = pd.to_numeric(df['TJ'], errors='coerce')
df['TJ'] = df['TJ'].abs()
df.dropna(subset=['TJ'], inplace=True)
df['TJ'] = df['TJ'].astype(int)
df = df[df['Rubrik'] == 'Endverbrauch - Total']

# Process data
energy_sum_by_year_and_type = df.groupby(['Jahr', 'Energietraeger'])['TJ'].sum().reset_index()
total_energy_by_year = df.groupby('Jahr')['TJ'].sum().reset_index()
total_energy_by_year.rename(columns={'TJ': 'TotalEnergy'}, inplace=True)
merged_df = pd.merge(energy_sum_by_year_and_type, total_energy_by_year, on='Jahr')
merged_df['Percentage'] = (merged_df['TJ'] / merged_df['TotalEnergy']) * 100

# Merge with population data
final_merged_df = pd.merge(merged_df, person_df, on='Jahr')
final_merged_df['Energy_per_head'] = final_merged_df['TotalEnergy'] / final_merged_df['Bevölkerung']

# Plotting with color mapping
fig, ax = plt.subplots(figsize=(12, 8))
bubble_sizes = final_merged_df['Energy_per_head'] * 1000  # Scale factor for visibility
colors = final_merged_df['Energy_per_head']  # This will map 'Energy_per_head' values to colors

# Normalize the colors to use with colormap
norm = plt.Normalize(colors.min(), colors.max())
cmap = plt.get_cmap('viridis')

scatter = ax.scatter(final_merged_df['Jahr'], final_merged_df['Bevölkerung'], s=bubble_sizes, c=colors, cmap=cmap, alpha=0.5, edgecolors='black')
plt.title('Population vs. Year with Energy per Head Proportional Symbol')
plt.xlabel('Year')
plt.ylabel('Population')

# Create a colorbar
cbar = plt.colorbar(scatter, ax=ax)
cbar.set_label('Energy per Head')

# Create a legend for bubble sizes
handles, labels = scatter.legend_elements(prop="sizes", alpha=0.5, num=5)
legend2 = ax.legend(handles, labels, loc="upper right", title="Bubble Size Scale")
plt.show()

# %% [markdown]
# ### 4.3.7 Analyse Entwickung Energieeffizienz (Sektoren und Bruttoverbrauch)

# %% [markdown]
# Um die Fragestellung in Bezug der Energieeffizienz zu beantworten, werden die Parameter der Sektoren mit dem Bruttoverbrauch analysiert. Dabei wird untersucht wie sich die Sektoren im Verhältnis zum gesamten Bruttoenergieverbrauch entwickelt hat.

# %%
# Welche Funktion(en) zur Datenanalyse ausführen?

#describe?
#head?
#info?
#...
#...
#Vorschlag: erste 5 und letzte 5 Zeilen des Dataframes

# %% [markdown]
# ### 4.3.8 Visualisierung Entwickung Energieeffizienz (Sektoren und Bruttoverbrauch)

# %% [markdown]
# Hier werden die analysierten Daten visualisiert und präsentiert.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Define your data as a multi-line string
df = pd.read_csv('https://raw.githubusercontent.com/michaelzimmermannstudhslu/BINA_2024_energy_research/main/data/co2_sector.csv')

# Set 'Jahr' as the index
df.set_index('Jahr', inplace=True)

# Plotting
plt.figure(figsize=(10, 6))

# Colors for each sector
colors = ['b', 'g', 'r', 'c']
years = np.arange(len(df))

# Add trend lines for each sector
for column, color in zip(df.columns, colors):
    z = np.polyfit(years, df[column], 1)  # Linear trend line
    p = np.poly1d(z)
    plt.plot(df.index, p(years), label=f'{column} Trend', color=color, linestyle='--')

plt.title('Trend Lines of Sector Contributions Over Time')
plt.xlabel('Year')
plt.ylabel('Contributions')
plt.legend()
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from scipy.signal import find_peaks, savgol_filter

# Load data
df = pd.read_csv('https://raw.githubusercontent.com/michaelzimmermannstudhslu/BINA_2024_energy_research/main/data/co2_sector.csv')

# Set 'Jahr' as the index
df.set_index('Jahr', inplace=True)

# Plotting the area chart
fig, ax = plt.subplots(figsize=(10, 6))
df.plot(kind='area', stacked=True, ax=ax)

# Calculate cumulative sum for total contributions per year
total_contributions = df.sum(axis=1)

# Use numpy to calculate a smoothed version of the total contributions
smoothed = savgol_filter(total_contributions, 9, 3)  # Using Savitzky-Golay filter for better smoothing

# Calculate second derivative
second_derivative = np.diff(smoothed, n=2)

# Define a threshold for "big changes"
threshold = np.percentile(np.abs(second_derivative), 95)  # top 5% magnitude changes

# Identify inflection points (zero crossings in the second derivative)
inflection_points = np.where(np.diff(np.sign(second_derivative)))[0] + 1  # Adjust for shift caused by diff

# Plot inflection points
for point in inflection_points:
    if point < len(df) and np.abs(second_derivative[point - 1]) > threshold:
        year = df.index[point]
        ax.plot(year, total_contributions.loc[year], 'ro')  # Mark inflection point with a red circle
        ax.axvline(x=year, color='black', linestyle='--', linewidth=1)  # Draw vertical line

# Fit trend lines for specified periods
# Trend line for 1990-2011
years_1990_2011 = np.arange(1990, 2012)
contributions_1990_2011 = total_contributions.loc[1990:2011]
coeffs_1990_2011 = np.polyfit(years_1990_2011, contributions_1990_2011, 1)
poly_1990_2011 = np.poly1d(coeffs_1990_2011)
ax.plot(years_1990_2011, poly_1990_2011(years_1990_2011), 'b--', label='1990-2011 Trend')

# Trend line for 2011-2021
years_2011_2021 = np.arange(2011, 2022)
contributions_2011_2021 = total_contributions.loc[2011:2021]
coeffs_2011_2021 = np.polyfit(years_2011_2021, contributions_2011_2021, 1)
poly_2011_2021 = np.poly1d(coeffs_2011_2021)
ax.plot(years_2011_2021, poly_2011_2021(years_2011_2021), 'b--', label='2011-2021 Trend')

# Customize the plot
plt.title('Stacked Area Chart of Sector Contributions Over Time with Significant Inflection Points')
plt.xlabel('Year')
plt.ylabel('Contributions')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 4.3.9 Analyse und Visualisierung Entwickung CO2 Emissionen

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# Define the data as a dictionary and convert it into a DataFrame
df = pd.read_csv('https://raw.githubusercontent.com/michaelzimmermannstudhslu/BINA_2024_energy_research/main/data/co2.csv')

print(df)
# Prepare the data for regression
X = df[['Jahr']]
y = df['THG']  # Response

# Create and fit the model
model = LinearRegression()
model.fit(X, y)

# Coefficients of the model
slope = model.coef_[0]
intercept = model.intercept_

# Predict when THG will be zero
# THG = intercept + slope * Jahr, set THG to 0 and solve for Jahr
if slope != 0:
    year_zero_emissions = int(-intercept / slope)
else:
    year_zero_emissions = "never" if intercept > 0 else "already at zero"

# Create a range of years for prediction
years_extended = np.arange(1990, year_zero_emissions + 1 if year_zero_emissions != "never" else 2050)
future_X = years_extended.reshape(-1, 1)

# Predict for extended years
predicted_THG = model.predict(future_X)

# Plotting
plt.figure(figsize=(10, 6))
plt.scatter(df['Jahr'], df['THG'], color='blue', label='Historical THG Data')
plt.plot(years_extended, predicted_THG, color='red', linestyle='--', label='Trend Line')
plt.axhline(0, color='green', linestyle='-', label='Zero Emissions Line')
plt.axvline(x=year_zero_emissions, color='purple', linestyle='--', label=f'Estimated Year: {year_zero_emissions}')

plt.title('Predicted Year for Zero Total Greenhouse Gas Emissions')
plt.xlabel('Year')
plt.ylabel('Total Greenhouse Gas Emissions (THG)')
plt.legend()
plt.grid(True)
plt.show()

# Output the estimated year of zero emissions
print(f"Estimated year when THG will reach zero based on the trend: {year_zero_emissions}")
# Out:
#     Jahr    THG
# 0   1990  55.34
# 1   1991  57.22
# 2   1992  56.94
# 3   1993  54.33
# 4   1994  53.26
# 5   1995  54.13
# 6   1996  54.76
# 7   1997  53.53
# 8   1998  55.04
# 9   1999  54.83
# 10  2000  54.07
# 11  2001  55.58
# 12  2002  54.01
# 13  2003  55.06
# 14  2004  55.64
# 15  2005  56.25
# 16  2006  55.92
# 17  2007  53.98
# 18  2008  55.36
# 19  2009  53.87
# 20  2010  55.46
# 21  2011  51.33
# 22  2012  52.66
# 23  2013  53.49
# 24  2014  49.55
# 25  2015  49.03
# 26  2016  49.34
# 27  2017  48.37
# 28  2018  46.86
# 29  2019  46.59
# 30  2020  43.91
# 31  2021  45.25
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# Estimated year when THG will reach zero based on the trend: 2181

# %% [markdown]
# # NOT IN USE (PLAYGROUND)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import ipywidgets as widgets
from IPython.display import display

df = pd.read_csv('https://raw.githubusercontent.com/michaelzimmermannstudhslu/BINA_2024_energy_research/main/data/energiebilanz_ch.csv')

#Clean up invalid rows
df_rein = df.dropna()

# Convert 'EnergyUsed' to numeric, set errors='coerce' to handle non-convertible values
df['TJ'] = pd.to_numeric(df['TJ'], errors='coerce')
df['TJ'] = df['TJ'].abs()

# Drop rows where 'EnergyUsed' is NaN after conversion
df = df.dropna(subset=['TJ'])

# Convert 'EnergyUsed' to integer
df['TJ'] = df['TJ'].astype(int)

df = df[df['Rubrik'] == 'Endverbrauch - Total']

energy_sum_by_year_and_type = df.groupby(['Jahr', 'Energietraeger'])['TJ'].sum().reset_index()
total_energy_by_year = df.groupby('Jahr')['TJ'].sum().reset_index()
total_energy_by_year.rename(columns={'TJ': 'TotalEnergy'}, inplace=True)

# Merge to get total energy per year alongside each row
merged_df = pd.merge(energy_sum_by_year_and_type, total_energy_by_year, on='Jahr')

# Calculate the percentage
merged_df['Percentage'] = (merged_df['TJ'] / merged_df['TotalEnergy']) * 100

print(merged_df)

def plot_pie(year):
    # Filter data for the selected year
    filtered_data = merged_df[merged_df['Jahr'] == year]
    labels = filtered_data['Energietraeger']
    sizes = filtered_data['Percentage']

    # Colors will be assigned by a colormap
    cmap = plt.get_cmap('tab20')  # Enhanced color map
    colors = [cmap(i) for i in np.linspace(0, 1, len(labels))]

    # Exploding the largest piece a little
    explode = [0.1 for i in sizes.index]

    # Create pie chart
    plt.figure(figsize=(10, 8))
    patches, texts, autotexts = plt.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=140, colors=colors, explode=explode, pctdistance=1.1)

    # Improve the display of the labels and percentage values
    for text, autotext in zip(texts, autotexts):
        text.set_fontsize(10)
        text.set_color('white')
        autotext.set_fontsize(10)

    # Add a legend
    plt.legend(patches, labels, title="Energy Types", loc="best", bbox_to_anchor=(1, 0, 0.5, 1))
    plt.title(f'Energy Usage Breakdown for {year}')
    plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
    plt.show()

# Link dropdown to the plotting function
widgets.interactive(plot_pie, year=year_dropdown)
# Out:
# Training score: 0.9829929503452884
# Test score: 0.9592965944795976
# [22.35985546 22.34815527 22.33645507 22.32475488 22.31305468 22.30135449
#  22.2896543 ]
# Year: 2023, Predicted Percentage: 22.36%
# Year: 2024, Predicted Percentage: 22.35%
# Year: 2025, Predicted Percentage: 22.34%
# Year: 2026, Predicted Percentage: 22.32%
# Year: 2027, Predicted Percentage: 22.31%
# Year: 2028, Predicted Percentage: 22.30%
# Year: 2029, Predicted Percentage: 22.29%
#      Jahr                Energietraeger      TJ  TotalEnergy  Percentage
# 0    1980                  Elektrizität  126910       698290   18.174397
# 1    1980                 Erdölprodukte  489480       698290   70.096951
# 2    1980                     Fernwärme    7920       698290    1.134199
# 3    1980                           Gas   30370       698290    4.349196
# 4    1980                   Holzenergie   26280       698290    3.763479
# ..    ...                           ...     ...          ...         ...
# 452  2022                           Gas  101650       765070   13.286366
# 453  2022                   Holzenergie   41270       765070    5.394278
# 454  2022                         Kohle    3850       765070    0.503222
# 455  2022     Müll und Industrieabfälle   12280       765070    1.605082
# 456  2022  Uebrige erneuerbare Energien   32260       765070    4.216608
#
# [457 rows x 5 columns]
# interactive(children=(Dropdown(description='Year:', index=41, options=(1980, 1981, 1982, 1983, 1984, 1985, 198…

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import ipywidgets as widgets
from IPython.display import display, clear_output
import time
import threading

df = pd.read_csv('https://raw.githubusercontent.com/michaelzimmermannstudhslu/BINA_2024_energy_research/main/data/energiebilanz_ch.csv')

#Clean up invalid rows
df_rein = df.dropna()



# Convert 'EnergyUsed' to numeric, set errors='coerce' to handle non-convertible values
df['TJ'] = pd.to_numeric(df['TJ'], errors='coerce')
df['TJ'] = df['TJ'].abs()

# Drop rows where 'EnergyUsed' is NaN after conversion
df = df.dropna(subset=['TJ'])



# Convert 'EnergyUsed' to integer
df['TJ'] = df['TJ'].astype(int)

df = df[df['Rubrik'] == 'Endverbrauch - Total']

energy_sum_by_year_and_type = df.groupby(['Jahr', 'Energietraeger'])['TJ'].sum().reset_index()
total_energy_by_year = df.groupby('Jahr')['TJ'].sum().reset_index()
total_energy_by_year.rename(columns={'TJ': 'TotalEnergy'}, inplace=True)

# Merge to get total energy per year alongside each row
merged_df = pd.merge(energy_sum_by_year_and_type, total_energy_by_year, on='Jahr')

# Calculate the percentage
merged_df['Percentage'] = (merged_df['TJ'] / merged_df['TotalEnergy']) * 100

print(merged_df)

def plot_histogram(year):
    # Filter data for the selected year from merged_df
    filtered_data = merged_df[merged_df['Jahr'] == year]

    # Generate a color map that has as many colors as there are unique 'Energietraeger'
    colors = plt.cm.viridis(np.linspace(0, 1, len(filtered_data['Energietraeger'].unique())))

    # Create histogram
    plt.figure(figsize=(10, 6))
    bars = plt.bar(filtered_data['Energietraeger'], filtered_data['Percentage'], color=colors)
    plt.xlabel('Energy Type')
    plt.ylabel('Energy Used (TJ)')
    plt.title(f'Energy Usage Distribution for {year}')
    plt.xticks(rotation=45)
    plt.ylim(0, 100)

    # Annotate the bars with the percentage value
    # Annotate the bars with the name of the 'Energietraeger'
    for bar, label in zip(bars, filtered_data['Percentage']):
        yval = bar.get_height()
        plt.text(bar.get_x() + bar.get_width()/2, yval + 2, f'{label:.2f}%', ha='center', va='bottom', color='black', fontsize=9)

    plt.show()

# Create a dropdown for year selection
year_dropdown = widgets.Dropdown(
    options=df['Jahr'].unique(),
    value=df['Jahr'].unique()[0],
    description='Year:',
    disabled=False,
)

widgets.interactive(plot_histogram, year=year_dropdown)
# Out:
#      Jahr                Energietraeger      TJ  TotalEnergy  Percentage
# 0    1980                  Elektrizität  126910       698290   18.174397
# 1    1980                 Erdölprodukte  489480       698290   70.096951
# 2    1980                     Fernwärme    7920       698290    1.134199
# 3    1980                           Gas   30370       698290    4.349196
# 4    1980                   Holzenergie   26280       698290    3.763479
# ..    ...                           ...     ...          ...         ...
# 452  2022                           Gas  101650       765070   13.286366
# 453  2022                   Holzenergie   41270       765070    5.394278
# 454  2022                         Kohle    3850       765070    0.503222
# 455  2022     Müll und Industrieabfälle   12280       765070    1.605082
# 456  2022  Uebrige erneuerbare Energien   32260       765070    4.216608
#
# [457 rows x 5 columns]
# interactive(children=(Dropdown(description='Year:', options=(1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987, 1…

# %%
import pandas as pd
import matplotlib.pyplot as plt
import ipywidgets as widgets
from IPython.display import display

df = pd.read_csv('https://raw.githubusercontent.com/michaelzimmermannstudhslu/BINA_2024_energy_research/main/data/energiebilanz_ch.csv')

#Clean up invalid rows
df_rein = df.dropna()

print("Content of the csv")
print(df_rein)

# Extrahieren der einzigartigen Zeichenketten
energietraeger = pd.DataFrame(df['Energietraeger'].unique(), columns=['Energietraeger'])

print("")
print("############")
print("############")
print("############")
print("Energytrager")
print(energietraeger)

# Extrahieren der einzigartigen Zeichenketten
rubrik = pd.DataFrame(df['Rubrik'].unique(), columns=['Rubrik'])

print(rubrik)

print("")
print("############")
print("############")
print("############")
print("Gesammt Energy Verbrauch pro Jahr")

# Convert 'EnergyUsed' to numeric, set errors='coerce' to handle non-convertible values
df['TJ'] = pd.to_numeric(df['TJ'], errors='coerce')

# Drop rows where 'EnergyUsed' is NaN after conversion
df = df.dropna(subset=['TJ'])

# Convert 'EnergyUsed' to integer
df['TJ'] = df['TJ'].astype(int)

groupRubrik = df.groupby('Jahr')['TJ'].sum().reset_index()
print(groupRubrik)


print("")
print("############")
print("############")
print("############")
print("Test")


count_by_year_and_type = df.groupby(['Jahr', 'Energietraeger'])['TJ'].sum().reset_index()

print(count_by_year_and_type)


print("")
print("############")
print("############")
print("############")
print("Test")


energy_sum_by_year_and_type = df.groupby(['Jahr', 'Energietraeger'])['TJ'].sum().reset_index()
total_energy_by_year = df.groupby('Jahr')['TJ'].sum().reset_index()
total_energy_by_year.rename(columns={'TJ': 'TotalEnergy'}, inplace=True)

# Merge to get total energy per year alongside each row
merged_df = pd.merge(energy_sum_by_year_and_type, total_energy_by_year, on='Jahr')

# Calculate the percentage
merged_df['Percentage'] = (merged_df['TJ'] / merged_df['TotalEnergy']) * 100

print(merged_df)


# Get unique years
#years = merged_df['Jahr'].unique()

# Plot pie chart for each year
#for year in years:
#    plt.figure()
#    subset = merged_df[merged_df['Jahr'] == year]
#    plt.pie(subset['Percentage'], labels=subset['Energietraeger'], autopct='%1.1f%%', startangle=140)
##    plt.title(f'Energy Usage Breakdown {year}')
#    plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

#plt.show()

def plot_pie(year):

    # Filter data for the selected year
    filtered_data = merged_df[merged_df['Jahr'] == year]

    # Create pie chart
    plt.figure(figsize=(8, 6))
    plt.pie(filtered_data['Percentage'], labels=filtered_data['Energietraeger'], autopct='%1.1f%%', startangle=140)
    plt.title(f'Energy Usage Breakdown for {year}')
    plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
    plt.show()
# Out:
# Content of the csv
#       Jahr                        Rubrik                Energietraeger  \
# 0     1980               Bruttoverbrauch                  Elektrizität
# 1     1980               Bruttoverbrauch                 Erdölprodukte
# 2     1980               Bruttoverbrauch                     Fernwärme
# 3     1980               Bruttoverbrauch                           Gas
# 4     1980               Bruttoverbrauch                   Holzenergie
# ...    ...                           ...                           ...
# 8982  2022  Nichtenergetischer Verbrauch                         Kohle
# 8983  2022  Nichtenergetischer Verbrauch     Müll und Industrieabfälle
# 8984  2022  Nichtenergetischer Verbrauch                         Rohöl
# 8985  2022  Nichtenergetischer Verbrauch  Uebrige erneuerbare Energien
# 8986  2022  Nichtenergetischer Verbrauch                   Wasserkraft
#
#                          TJ
# 0                    -29450
# 1                    321250
# 2                         0
# 3                     36280
# 4                     26280
# ...                     ...
# 8982  keine Daten verfügbar
# 8983  keine Daten verfügbar
# 8984  keine Daten verfügbar
# 8985  keine Daten verfügbar
# 8986  keine Daten verfügbar
#
# [8987 rows x 4 columns]
#
# ############
# ############
# ############
# Energytrager
#                   Energietraeger
# 0                   Elektrizität
# 1                  Erdölprodukte
# 2                      Fernwärme
# 3                            Gas
# 4                    Holzenergie
# 5                Kernbrennstoffe
# 6                          Kohle
# 7      Müll und Industrieabfälle
# 8                          Rohöl
# 9   Uebrige erneuerbare Energien
# 10                   Wasserkraft
#                                                Rubrik
# 0                                     Bruttoverbrauch
# 1   Eigenverbrauch des Energiesektors, Netzverlust...
# 2                     Endverbrauch - Dienstleistungen
# 3                            Endverbrauch - Haushalte
# 4                            Endverbrauch - Industrie
# 5   Endverbrauch - Statistische Differenz inkl. La...
# 6                                Endverbrauch - Total
# 7                              Endverbrauch - Verkehr
# 8             Energieumwandlung - Diverse Erneuerbare
# 9                        Energieumwandlung - Gaswerke
# 10                 Energieumwandlung - Kernkraftwerke
# 11                    Energieumwandlung - Raffinerien
# 12               Energieumwandlung - Wasserkraftwerke
# 13  Energieumwandlung - konventionell-thermische K...
# 14                                             Export
# 15                                             Import
# 16                                   Inlandproduktion
# 17                                   Lagerveränderung
# 18                       Nichtenergetischer Verbrauch
#
# ############
# ############
# ############
# Gesammt Energy Verbrauch pro Jahr
#     Jahr       TJ
# 0   1980  2935400
# 1   1981  2921320
# 2   1982  2854330
# 3   1983  2929150
# 4   1984  3064950
# 5   1985  3141800
# 6   1986  3203540
# 7   1987  3244390
# 8   1988  3254340
# 9   1989  3266710
# 10  1990  3402570
# 11  1991  3563140
# 12  1992  3577490
# 13  1993  3481130
# 14  1994  3414460
# 15  1995  3514980
# 16  1996  3600870
# 17  1997  3539480
# 18  1998  3642840
# 19  1999  3665420
# 20  2000  3651180
# 21  2001  3746790
# 22  2002  3642790
# 23  2003  3726430
# 24  2004  3738970
# 25  2005  3767140
# 26  2006  3793370
# 27  2007  3695770
# 28  2008  3832970
# 29  2009  3750250
# 30  2010  3897960
# 31  2011  3657450
# 32  2012  3771390
# 33  2013  3863330
# 34  2014  3595850
# 35  2015  3607400
# 36  2016  3655220
# 37  2017  3640770
# 38  2018  3599730
# 39  2019  3617530
# 40  2020  3249790
# 41  2021  3404150
# 42  2022  3320590
#
# ############
# ############
# ############
# Test
#      Jahr                Energietraeger       TJ
# 0    1980                  Elektrizität   351280
# 1    1980                 Erdölprodukte  1789690
# 2    1980                     Fernwärme    23760
# 3    1980                           Gas   127390
# 4    1980                   Holzenergie   105120
# ..    ...                           ...      ...
# 458  2022                         Kohle    15400
# 459  2022     Müll und Industrieabfälle    95380
# 460  2022                         Rohöl   132710
# 461  2022  Uebrige erneuerbare Energien   147700
# 462  2022                   Wasserkraft   120600
#
# [463 rows x 3 columns]
#
# ############
# ############
# ############
# Test
#      Jahr                Energietraeger       TJ  TotalEnergy  Percentage
# 0    1980                  Elektrizität   351280      2935400   11.967023
# 1    1980                 Erdölprodukte  1789690      2935400   60.969204
# 2    1980                     Fernwärme    23760      2935400    0.809430
# 3    1980                           Gas   127390      2935400    4.339783
# 4    1980                   Holzenergie   105120      2935400    3.581113
# ..    ...                           ...      ...          ...         ...
# 458  2022                         Kohle    15400      3320590    0.463773
# 459  2022     Müll und Industrieabfälle    95380      3320590    2.872381
# 460  2022                         Rohöl   132710      3320590    3.996579
# 461  2022  Uebrige erneuerbare Energien   147700      3320590    4.448005
# 462  2022                   Wasserkraft   120600      3320590    3.631885
#
# [463 rows x 5 columns]

# %%
import pandas as pd
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import itertools

# Load the energy data from an online source into a table called a DataFrame.
df = pd.read_csv('https://raw.githubusercontent.com/michaelzimmermannstudhslu/BINA_2024_energy_research/main/data/energiebilanz_ch.csv')

# Remove any rows that have missing data to ensure data quality.
df = df.dropna()

# Convert energy usage data to a numeric type, forcing errors to be recognized as NaN (not a number), and make all values positive.
df['TJ'] = pd.to_numeric(df['TJ'], errors='coerce')
df['TJ'] = df['TJ'].abs()

# Remove any rows where energy usage data couldn't be converted to numbers.
df = df.dropna(subset=['TJ'])

# Only consider data where the category is 'Endverbrauch - Total', which stands for 'Total final consumption'.
df = df[df['Rubrik'] == 'Endverbrauch - Total']

# Group data by year and type of energy, and sum up all energy usage values.
energy_sum_by_year_and_type = df.groupby(['Jahr', 'Energietraeger'])['TJ'].sum().reset_index()
total_energy_by_year = df.groupby('Jahr')['TJ'].sum().reset_index()

# Rename the column for clearer understanding.
total_energy_by_year.rename(columns={'TJ': 'TotalEnergy'}, inplace=True)

# Merge the two datasets on the year column, so each row shows total energy and energy by type for each year.
merged_df = pd.merge(energy_sum_by_year_and_type, total_energy_by_year, on='Jahr')

# Calculate what percentage of the total energy each type represents per year.
merged_df['Percentage'] = (merged_df['TJ'] / merged_df['TotalEnergy']) * 100

# Prepare data for the model by creating dummy variables for each type of energy (one-hot encoding).
df_for_model = merged_df[['Jahr', 'Energietraeger', 'Percentage']].copy()
df_for_model = pd.get_dummies(df_for_model, columns=['Energietraeger'])

# Separate the data into input features (X) and output targets (y), where y is the percentage to predict.
X = df_for_model.drop('Percentage', axis=1).values
y = df_for_model['Percentage'].values

# Standardize features by removing the mean and scaling to unit variance to help the model learn more effectively.
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Split data into training set and test set, where 20% of the data is reserved for testing the model.
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# Convert arrays to tensors, which are a type of data structure used in PyTorch for building models.
X_train = torch.tensor(X_train, dtype=torch.float32)
y_train = torch.tensor(y_train, dtype=torch.float32)
X_test = torch.tensor(X_test, dtype=torch.float32)
y_test = torch.tensor(y_test, dtype=torch.float32)

# Define a simple linear regression model using a neural network framework.
class LinearRegressionModel(nn.Module):
    def __init__(self, input_size):
        super(LinearRegressionModel, self).__init__()
        self.linear = nn.Linear(input_size, 1)

    def forward(self, x):
        return self.linear(x)

# Initialize the model with the correct number of input features.
model = LinearRegressionModel(X_train.shape[1])

# Define a mean squared error loss function and the stochastic gradient descent optimizer.
criterion = nn.MSELoss()
optimizer = optim.SGD(model.parameters(), lr=0.01)

# Train the model for 100 epochs, updating weights to minimize the loss.
epochs = 100
for epoch in range(epochs):
    model.train()
    optimizer.zero_grad()

    # Perform a forward pass (calculate predicted y from x), and compute the loss.
    outputs = model(X_train).squeeze()
    loss = criterion(outputs, y_train)

    # Perform a backward pass to compute gradients, and update model weights.
    loss.backward()
    optimizer.step()

    # Print the loss every 10 epochs to monitor progress.
    if (epoch+1) % 10 == 0:
        print(f'Epoch [{epoch+1}/{epochs}], Loss: {loss.item():.4f}')

# Prepare data for predicting future energy percentages for years 2025-2051 for each type of energy.
unique_energy_types = merged_df['Energietraeger'].unique()
future_years = np.arange(2025, 2051)
future_data = pd.DataFrame(list(itertools.product(future_years, unique_energy_types)), columns=['Jahr', 'Energietraeger'])
future_data = pd.get_dummies(future_data, columns=['Energietraeger'])

# Add missing columns with zeros in case some energy types were not present in the future data.
missing_cols = set(df_for_model.columns) - set(future_data.columns) - {'Percentage'}
for col in missing_cols:
    future_data[col] = 0

# Scale the future data features and convert to tensor.
future_features = scaler.transform(future_data)
future_features = torch.tensor(future_features, dtype=torch.float32)

# Use the trained model to predict future energy percentages.
model.eval()
with torch.no_grad():
    future_predictions = model(future_features).squeeze()

# Clamp output to ensure no negative percentages.
outputs = torch.clamp(outputs, min=0, max=100)

# Store the predicted percentages back in the data frame.
future_data['Predicted_Percentage'] = future_predictions.numpy()

# Function to revert one-hot encoded columns back to a single categorical column for easier interpretation.
def revert_dummies(revert_df, prefix):
    category_cols = [col for col in revert_df if col.startswith(prefix)]
    revert_df['Energietraeger'] = revert_df[category_cols].idxmax(axis=1)
    revert_df['Energietraeger'] = revert_df['Energietraeger'].apply(lambda x: x.replace(prefix + '_', ''))
    revert_df.drop(columns=category_cols, inplace=True)
    return revert_df

# Apply the function to revert dummy variables.
real_future_data = revert_dummies(future_data, 'Energietraeger')
real_future_data['Predicted_Percentage'] = real_future_data['Predicted_Percentage'].clip(lower=0)
print(real_future_data)

# Function to plot a histogram showing the distribution of predicted energy usage percentages by energy type for a selected year.
def plot_histogram(year):
    filtered_data = real_future_data[real_future_data['Jahr'] == year]
    colors = plt.cm.viridis(np.linspace(0, 1, len(filtered_data['Energietraeger'].unique())))
    plt.figure(figsize=(10, 6))
    bars = plt.bar(filtered_data['Energietraeger'], filtered_data['Predicted_Percentage'], color=colors)
    plt.xlabel('Energy Type')
    plt.ylabel('Energy Used (TJ)')
    plt.title(f'Energy Usage Distribution for {year}')
    plt.xticks(rotation=45)
    plt.ylim(0, 100)
    for bar, label in zip(bars, filtered_data['Predicted_Percentage']):
        yval = bar.get_height()
        plt.text(bar.get_x() + bar.get_width()/2, yval + 2, f'{label:.2f}%', ha='center', va='bottom', color='black', fontsize=9)
    plt.show()

# Create a dropdown menu for selecting a year to visualize, and link it to the plotting function.
year_dropdown = widgets.Dropdown(
    options=real_future_data['Jahr'].unique(),
    value=real_future_data['Jahr'].unique()[0],
    description='Year:',
    disabled=False,
)

widgets.interactive(plot_histogram, year=year_dropdown)
# Out:
# Epoch [10/100], Loss: 275.5193
# Epoch [20/100], Loss: 170.1424
# Epoch [30/100], Loss: 106.0906
# Epoch [40/100], Loss: 67.0889
# Epoch [50/100], Loss: 43.2954
# Epoch [60/100], Loss: 28.7507
# Epoch [70/100], Loss: 19.8406
# Epoch [80/100], Loss: 14.3697
# Epoch [90/100], Loss: 11.0026
# Epoch [100/100], Loss: 8.9249
#      Jahr  Predicted_Percentage                Energietraeger
# 0    2025             19.572664                  Elektrizität
# 1    2025             53.073021                 Erdölprodukte
# 2    2025              1.105239                     Fernwärme
# 3    2025              9.093404                           Gas
# 4    2025              3.184221                   Holzenergie
# ..    ...                   ...                           ...
# 281  2050              0.543593                         Kohle
# 282  2050              0.638563     Müll und Industrieabfälle
# 283  2050              0.000000                         Rohöl
# 284  2050              0.000000                   Wasserkraft
# 285  2050              0.791524  Uebrige erneuerbare Energien
#
# [286 rows x 3 columns]
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:432: UserWarning: X has feature names, but StandardScaler was fitted without feature names
#   warnings.warn(
# interactive(children=(Dropdown(description='Year:', options=(2025, 2026, 2027, 2028, 2029, 2030, 2031, 2032, 2…

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Load data
person_df = pd.read_csv('https://raw.githubusercontent.com/michaelzimmermannstudhslu/BINA_2024_energy_research/main/data/bip_total.csv')
energy_df = pd.read_csv('https://raw.githubusercontent.com/michaelzimmermannstudhslu/BINA_2024_energy_research/main/data/energiebilanz_ch.csv')

# Clean and process energy data
energy_df.dropna(inplace=True)
energy_df['TJ'] = pd.to_numeric(energy_df['TJ'], errors='coerce')
energy_df['TJ'] = energy_df['TJ'].abs()
energy_df.dropna(subset=['TJ'], inplace=True)
energy_df['TJ'] = energy_df['TJ'].astype(int)
energy_df = energy_df[energy_df['Rubrik'] == 'Endverbrauch - Total']

# Summarize energy data by year
total_energy_by_year = energy_df.groupby('Jahr')['TJ'].sum().reset_index()
total_energy_by_year.rename(columns={'TJ': 'TotalEnergy'}, inplace=True)

# Merge energy data with population data
final_merged_df = pd.merge(total_energy_by_year, person_df, on='Jahr')
final_merged_df['Energy_per_head'] = final_merged_df['TotalEnergy'] / final_merged_df['Bevölkerung']
final_merged_df['BIP_per_head'] = final_merged_df['BIP'] / final_merged_df['Bevölkerung']

# Calculate the annual change in BIP_per_head to find turning points
final_merged_df['BIP_change'] = final_merged_df['BIP_per_head'].pct_change()

# Identify turning points where the change in BIP_per_head changes sign
turning_points = final_merged_df[(final_merged_df['BIP_change'].shift(1) * final_merged_df['BIP_change'] < 0)]

# Create the plot
fig, ax1 = plt.subplots(figsize=(14, 7))

# Plot BIP per Head
color = 'tab:blue'
ax1.plot(final_merged_df['Jahr'], final_merged_df['BIP_per_head'], color=color, label='BIP_per_head')
ax1.set_xlabel('Jahr')
ax1.set_ylabel('BIP per Head', color=color)
ax1.tick_params(axis='y', labelcolor=color)

# Mark turning points
ax1.plot(turning_points['Jahr'], turning_points['BIP_per_head'], 'go')  # 'go' for green circles

x_values = [final_merged_df['Jahr'].values[0], turning_points['Jahr'].values[0]]
y_values = [final_merged_df['BIP_per_head'].values[0], turning_points['BIP_per_head'].values[0]]
ax1.plot(x_values, y_values, 'g--')  # Green dashed line between points

# Draw lines between turning points
for i in range(len(turning_points['Jahr']) - 1):
    x_values = [turning_points['Jahr'].values[i], turning_points['Jahr'].values[i + 1]]
    y_values = [turning_points['BIP_per_head'].values[i], turning_points['BIP_per_head'].values[i + 1]]
    ax1.plot(x_values, y_values, 'g--')  # Green dashed line between points

# Plot Population on the primary y-axis
ax2 = ax1.twinx()
color = 'red'  # Set the color variable to red
ax2.plot(final_merged_df['Jahr'], final_merged_df['Bevölkerung'], color=color, label='Bevölkerung')  # Use 'color' variable
ax2.set_xlabel('Jahr')
ax2.set_ylabel('Bevölkerung', color=color)  # Set label color to red
ax2.tick_params(axis='y', labelcolor=color)  # Set tick color to red


# Title and legend
plt.title('Bevölkerung und BIP pro Kopf der Schweiz mit Wendepunkten (1980 - 2022)')
lines1, labels1 = ax1.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
plt.legend(lines1 + lines2, labels1 + labels2, loc='upper left')

fig.tight_layout()
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# Create DataFrame
df = pd.read_csv('https://raw.githubusercontent.com/michaelzimmermannstudhslu/BINA_2024_energy_research/main/data/bip_total.csv')
df = df.dropna()

# Initialize the linear regression model
model_population = LinearRegression()
model_gdp = LinearRegression()

# Prepare data for regression (reshape year data for fitting)
X = df['Jahr'].values.reshape(-1, 1)  # Features
y_population = df['Bevölkerung'].values  # Target for population
y_gdp = df['BIP'].values  # Target for GDP

# Fit the models
model_population.fit(X, y_population)
model_gdp.fit(X, y_gdp)

# Predict the values
y_population_pred = model_population.predict(X)
y_gdp_pred = model_gdp.predict(X)

fig, ax1 = plt.subplots(figsize=(14, 7))

# Plot population data
color = 'tab:red'
ax1.set_xlabel('Jahr')
ax1.set_ylabel('Bevölkerung', color=color)
ax1.plot(df['Jahr'], df['Bevölkerung'], marker='o', color=color, label='Actual Bevölkerung')
ax1.plot(df['Jahr'], y_population_pred, color=color, linestyle='--', label='Regression Line - Bevölkerung')
ax1.tick_params(axis='y', labelcolor=color)

# Second y-axis for GDP
ax2 = ax1.twinx()
color = 'tab:blue'
ax2.set_ylabel('BIP', color=color)
ax2.plot(df['Jahr'], df['BIP'], marker='o', color=color, label='Actual BIP')
ax2.plot(df['Jahr'], y_gdp_pred, color=color, linestyle='--', label='Regression Line - BIP')
ax2.tick_params(axis='y', labelcolor=color)

# Title and legend
plt.title('Bevölkerung und BIP der Schweiz mit Regression (1980 - 2022)')
fig.tight_layout()

# Handling legends for both axes
lines, labels = ax1.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
ax1.legend(lines + lines2, labels + labels2, loc='upper left')
ax2.legend(lines + lines2, labels + labels2, loc='upper left')
plt.show()

# %%
import pandas as pd

df = pd.read_csv('https://raw.githubusercontent.com/michaelzimmermannstudhslu/BINA_2024_energy_research/main/data/bip_total.csv')

#probably better down the line for calculations and graphics but int looks nicer in the table
#df['Jahr'] = pd.to_datetime(df['Jahr'], format='%Y')

# Assuming we have a columns 'Bevölkerung' and 'Jahr' with integers that exceed the range of int16 (-32,768 to 32,767),
# but these numbers are still within the range of int32 (-2,147,483,648 to 2,147,483,647).
# In this case, using 'int32' is necessary to correctly handle the larger numbers without overflow,
# while also being more memory-efficient than opting for 'Int64' when the numbers do not require that range.
# This choice ensures data integrity and efficient memory use.
df['Jahr'] = df['Jahr'].astype('Int64')
df['Bevölkerung'] = df['Bevölkerung'].astype('Int64')

df
# Out:
#     Jahr  Bevölkerung        BIP  Inflationsrate
# 0   1980      6335243  205370.18             4.0
# 1   1981      6372904  220471.25             6.5
# 2   1982      6409713  233572.55             5.7
# 3   1983      6427833  240628.98             2.9
# 4   1984      6455896  257187.15             2.9
# 5   1985      6484834  272689.73             3.4
# 6   1986      6523413  286186.86             0.8
# 7   1987      6566799  297101.28             1.4
# 8   1988      6619973  315400.60             1.9
# 9   1989      6673850  340440.35             3.2
# 10  1990      6750693  369198.76             5.4
# 11  1991      6842768  385605.03             5.9
# 12  1992      6907959  393625.51             4.0
# 13  1993      6968570  402258.17             3.3
# 14  1994      7019019  412190.66             0.9
# 15  1995      7062354  417228.34             1.8
# 16  1996      7081346  420368.49             0.8
# 17  1997      7096465  427826.11             0.5
# 18  1998      7123537  439954.88             0.0
# 19  1999      7164444  447465.79             0.8
# 20  2000      7204055  471540.04             1.6
# 21  2001      7255653  483636.92             1.0
# 22  2002      7313853  482077.20             0.6
# 23  2003      7364148  487606.52             0.6
# 24  2004      7415102  502265.68             0.8
# 25  2005      7459128  520848.32             1.2
# 26  2006      7508739  553721.55             1.1
# 27  2007      7593494  589085.16             0.7
# 28  2008      7701856  614407.72             2.4
# 29  2009      7785806  603039.07            -0.5
# 30  2010      7864012  624545.12             0.7
# 31  2011      7954662  635738.74             0.2
# 32  2012      8039060  643645.59            -0.7
# 33  2013      8139631  654611.67            -0.2
# 34  2014      8237666  665618.37             0.0
# 35  2015      8327126  668006.38            -1.1
# 36  2016      8419550  677848.33            -0.4
# 37  2017      8484130  684558.47             0.5
# 38  2018      8544527  709521.56             0.9
# 39  2019      8606033  716878.59             0.4
# 40  2020      8670300  696619.96            -0.7
# 41  2021      8738791  743330.23             0.6
# 42  2022      8815385  781460.27             2.8
# 43  <NA>         <NA>        NaN             2.1

# %%
import pandas as pd

df = pd.read_csv('https://raw.githubusercontent.com/michaelzimmermannstudhslu/BINA_2024_energy_research/main/data/bip_per_head.csv')

#probably better down the line for calculations and graphics but int looks nicer in the table
#df['Jahr'] = pd.to_datetime(df['Jahr'], format='%Y')

# Assuming we have a columns 'Bevölkerung' and 'Jahr' with integers that exceed the range of int16 (-32,768 to 32,767),
# but these numbers are still within the range of int32 (-2,147,483,648 to 2,147,483,647).
# In this case, using 'int32' is necessary to correctly handle the larger numbers without overflow,
# while also being more memory-efficient than opting for 'Int64' when the numbers do not require that range.
# This choice ensures data integrity and efficient memory use.
df['Jahr'] = df['Jahr'].astype('Int64')
df['Bevölkerung'] = df['Bevölkerung'].astype('Int64')

df
# Out:
#     Jahr  Bevölkerung  BIP pro Kopf  Inflationsrate
# 0   1980      6335243      32163.32             4.0
# 1   1981      6372904      34292.34             6.5
# 2   1982      6409713      36116.28             5.7
# 3   1983      6427833      37122.79             2.9
# 4   1984      6455896      39535.94             2.9
# 5   1985      6484834      41738.30             3.4
# 6   1986      6523413      43540.14             0.8
# 7   1987      6566799      44886.05             1.4
# 8   1988      6619973      47275.56             1.9
# 9   1989      6673850      50637.84             3.2
# 10  1990      6750693      54766.83             5.4
# 11  1991      6842768      56459.71             5.9
# 12  1992      6907959      57057.36             4.0
# 13  1993      6968570      57740.06             3.3
# 14  1994      7019019      58559.21             0.9
# 15  1995      7062354      58802.08             1.8
# 16  1996      7081346      58953.01             0.8
# 17  1997      7096465      59832.44             0.5
# 18  1998      7123537      61354.43             0.0
# 19  1999      7164444      62063.31             0.8
# 20  2000      7204055      65047.12             1.6
# 21  2001      7255653      66429.52             1.0
# 22  2002      7313853      65734.21             0.6
# 23  2003      7364148      65999.87             0.6
# 24  2004      7415102      67523.35             0.8
# 25  2005      7459128      69610.07             1.2
# 26  2006      7508739      73582.89             1.1
# 27  2007      7593494      77627.01             0.7
# 28  2008      7701856      79999.84             2.4
# 29  2009      7785806      77565.90            -0.5
# 30  2010      7864012      79502.43             0.7
# 31  2011      7954662      80347.16             0.2
# 32  2012      8039060      80487.28            -0.7
# 33  2013      8139631      80922.70            -0.2
# 34  2014      8237666      81285.50             0.0
# 35  2015      8327126      80653.76            -1.1
# 36  2016      8419550      80953.18            -0.4
# 37  2017      8484130      80995.20             0.5
# 38  2018      8544527      83332.65             0.9
# 39  2019      8606033      83598.27             0.4
# 40  2020      8670300      80644.42            -0.7
# 41  2021      8738791      85395.64             0.6
# 42  2022      8815385      88717.09             2.8
